# %%
import datetime as datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("sell2013.csv", low_memory=False)

# %%
df.head()
# Out:
#    created_on operation property_type       place_name  \
# 0  2012-08-08      sell     apartment         Belgrano
# 1  2012-08-08      sell     apartment  Villa Ballester
# 2  2012-08-08      sell         house  Villa Ballester
# 3  2012-08-08      sell         house  Villa Ballester
# 4  2012-08-08      sell     apartment     Loma Hermosa
#
#                              place_with_parent_names  geonames_id  \
# 0               |Argentina|Capital Federal|Belgrano|    3436077.0
# 1  |Argentina|Bs.As. G.B.A. Zona Norte|General Sa...    3427467.0
# 2  |Argentina|Bs.As. G.B.A. Zona Norte|General Sa...    3427467.0
# 3  |Argentina|Bs.As. G.B.A. Zona Norte|General Sa...    3427467.0
# 4  |Argentina|Bs.As. G.B.A. Zona Oeste|Tres de Fe...          NaN
#
#                  lat-lon        lat        lon     price currency  \
# 0  -34.561208,-58.464514 -34.561208 -58.464514       NaN      NaN
# 1   -34.54673,-58.550579 -34.546730 -58.550579       NaN      NaN
# ...

# %%
df2 = df.groupby(['created_on', 'place_name'])[ 'price'].agg(['sum', 'count']).reset_index()

# %%
def asd: 
    return
# Out:
#        created_on               place_name        sum  count
# 2      2012-08-08              Las Cañitas   600000.0      1
# 4      2012-08-08                    Pilar   650000.0      1
# 5      2012-08-08               San Martín    99000.0      1
# 6      2012-08-08                    Tigre   410000.0      2
# 7      2012-08-08          Villa Ballester   110000.0      1
# 8      2012-08-09                   Flores   220000.0      1
# 9      2012-08-15                 Floresta    51900.0      1
# 10     2012-08-15        Parque Centenario   195000.0      1
# 12     2012-08-17                  Liniers   115000.0      1
# 13     2012-08-18                    Tigre   195000.0      1
# 14     2012-08-29             Constitución   130200.0      2
# 15     2012-09-12                    Tigre  1100000.0      1
# 16     2012-09-19                    Pilar   320000.0      1
# 17     2012-09-19                 Recoleta   418500.0      2
# ...
