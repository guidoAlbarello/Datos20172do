# %%
import datetime as datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('default') # Make the graphs a bit prettier
plt.rcParams['figure.figsize'] = (15, 5)

# %%
dsSell2013 = pd.read_csv("C:\sell2013.csv", low_memory=False)
dsSell2014 = pd.read_csv("C:\sell2014.csv", low_memory=False)
dsSell2015 = pd.read_csv("C:\sell2015.csv", low_memory=False)
dsSell2016 = pd.read_csv("C:\sell2016.csv", low_memory=False)
dsSell2017 = pd.read_csv("C:\sell2017.csv", low_memory=False)

# %%
dsSell2013.columns
# Out:
# Index([u'created_on', u'operation', u'property_type', u'place_name',
#        u'place_with_parent_names', u'geonames_id', u'lat-lon', u'lat', u'lon',
#        u'price', u'currency', u'price_aprox_local_currency',
#        u'price_aprox_usd', u'surface_in_m2', u'price_usd_per_m2', u'floor',
#        u'rooms', u'expenses', u'properati_url', u'image_thumbnail'],
#       dtype='object')

# %%
dsSell2014.columns
# Out:
# Index([u'created_on', u'operation', u'property_type', u'place_name',
#        u'place_with_parent_names', u'geonames_id', u'lat-lon', u'lat', u'lon',
#        u'price', u'currency', u'price_aprox_local_currency',
#        u'price_aprox_usd', u'surface_in_m2', u'price_usd_per_m2', u'floor',
#        u'rooms', u'expenses', u'properati_url', u'image_thumbnail'],
#       dtype='object')

# %%
dsSell2015.columns
# Out:
# Index([u'created_on', u'operation', u'property_type', u'place_name',
#        u'place_with_parent_names', u'geonames_id', u'lat-lon', u'lat', u'lon',
#        u'price', u'currency', u'price_aprox_local_currency',
#        u'price_aprox_usd', u'surface_total_in_m2', u'surface_covered_in_m2',
#        u'price_usd_per_m2', u'price_per_m2', u'floor', u'rooms', u'expenses',
#        u'properati_url', u'description', u'title', u'extra',
#        u'image_thumbnail'],
#       dtype='object')

# %%
#unimos todos los csv y filtramos para que solo queda GBA y CABA
dsSell = dsSell2013.append(dsSell2014).append(dsSell2015).append(dsSell2016).append(dsSell2017)

# %%
dsSell.head()
# Out:
#   country_name  created_on currency description   expenses extra  floor  \
# 0          NaN  2012-08-08      NaN         NaN  850 aprox   NaN   10.0
# 1          NaN  2012-08-08      NaN         NaN        NaN   NaN   11.0
# 2          NaN  2012-08-08      NaN         NaN        NaN   NaN    NaN
# 3          NaN  2012-08-08      USD         NaN        NaN   NaN    NaN
# 4          NaN  2012-08-08      NaN         NaN        NaN   NaN    NaN
#
#    geonames_id   id                                    image_thumbnail  ...    \
# 0    3436077.0  NaN  http://cf-thumbs.properati.com.ar/Cry7pVKa41t_...  ...
# 1    3427467.0  NaN  http://cf-thumbs.properati.com.ar/MwrzW_dkQbqR...  ...
# 2    3427467.0  NaN  http://cf-thumbs.properati.com.ar/2wMqxAsh1N2t...  ...
# 3    3427467.0  NaN  http://cf-thumbs.properati.com.ar/uMwzJsvexa1C...  ...
# 4          NaN  NaN  http://cf-thumbs.properati.com.ar/4kPnofvgR6hs...  ...
#
#    price_per_m2 price_usd_per_m2  \
# 0           NaN              NaN
# 1           NaN              NaN
# 2           NaN              NaN
# 3           NaN       315.186246
# 4           NaN              NaN
#
#                                        properati_url property_type rooms  \
# 0  http://www.properati.com.ar/ag_venta_departame...     apartment   3.0
# 1  http://www.properati.com.ar/ah_venta_departame...     apartment   3.0
# 2  http://www.properati.com.ar/aj_venta_casa_vill...         house   4.0
# 3  http://www.properati.com.ar/ak_venta_casa_vill...         house   4.0
# 4  http://www.properati.com.ar/ao_venta_departame...     apartment   3.0
#
#   state_name  surface_covered_in_m2  surface_in_m2  surface_total_in_m2  title
# 0        NaN                    NaN          102.0                  NaN    NaN
# 1        NaN                    NaN           73.0                  NaN    NaN
# 2        NaN                    NaN          485.0                  NaN    NaN
# 3        NaN                    NaN          349.0                  NaN    NaN
# 4        NaN                    NaN            NaN                  NaN    NaN
#
# [5 rows x 29 columns]

# %%
#Queremos quedarnos con la zona, el municipio y los que esten en CABA y GBA

dsSell['municipio'] = dsSell['place_with_parent_names'].apply(lambda x: x.split('|')[3])
dsSell['zona'] = dsSell['place_with_parent_names'].apply(lambda x: x.split('|')[2])

dsSell['filtro'] = dsSell['zona'].apply(lambda x: ((x=='Capital Federal')or(x=='Bs.As. G.B.A. Zona Norte')or(x=='Bs.As. G.B.A. Zona Sur')or(x=='Bs.As. G.B.A. Zona Oeste')))
dsSell = dsSell[dsSell.filtro]
dsSell.drop('filtro', axis=1, inplace=True)

# %%
#Como nos importa mucho el precio con respecto a otras cosas vamos a sacar a los que tienen esa columna en NaN

dsSell['tiene_precio'] = dsSell['price'].apply(lambda x: pd.notnull(x))
dsSell = dsSell[dsSell.tiene_precio]
dsSell.drop('tiene_precio', axis=1, inplace=True)

# %%
dsSell.groupby('municipio').price_aprox_usd.mean().head()
# Out:
# municipio
#                    270231.721642
# Abasto             155498.772601
# Agronomía          157318.141667
# Almagro            148182.569555
# Almirante Brown    196867.297707
# Name: price_aprox_usd, dtype: float64

# %%
dsSell.columns
# Out:
# Index([u'country_name', u'created_on', u'currency', u'description',
#        u'expenses', u'extra', u'floor', u'geonames_id', u'id',
#        u'image_thumbnail', u'lat', u'lat-lon', u'lon', u'operation',
#        u'place_name', u'place_with_parent_names', u'price',
#        u'price_aprox_local_currency', u'price_aprox_usd', u'price_per_m2',
#        u'price_usd_per_m2', u'properati_url', u'property_type', u'rooms',
#        u'state_name', u'surface_covered_in_m2', u'surface_in_m2',
#        u'surface_total_in_m2', u'title', u'municipio', u'zona'],
#       dtype='object')

# %%
#cuantos tipos de vivienda se vende

dsSell['property_type'].value_counts()
# Out:
# apartment    173536
# house        101135
# PH            19129
# store          8020
# Name: property_type, dtype: int64

# %%
#lugares donde mas se vende
dsSell['place_name'].value_counts()
# Out:
# Tigre                                  12115
# Nordelta                               11696
# Capital Federal                        11499
# Pilar                                  10249
# Belgrano                                9505
# Ramos Mejía                             9379
# Palermo                                 8294
# Caballito                               6364
# Olivos                                  6311
# Morón                                   5211
# San Isidro                              5119
# Villa Urquiza                           4635
# Benavidez                               4610
# Villa Crespo                            4398
# Barrio Norte                            4332
# Recoleta                                4257
# Flores                                  4241
# Martínez                                4208
# Haedo                                   4072
# Ituzaingó                               4045
# La Plata                                3942
# Vicente López                           3845
# Almagro                                 3710
# San Fernando                            3685
# San Miguel                              3518
# Nuñez                                   3143
# Balvanera                               3069
# Bs.As. G.B.A. Zona Norte                2973
# San Martín                              2900
# Lomas de Zamora                         2647
#                                        ...
# Barrio Cerrado "La Escondida"              1
# El Viejo Vivero                            1
# San Carlos Country Club - Entrada          1
# Área de Promoción El Triángulo             1
# Barrio Cerrado "La Reserva"                1
#  los alamos                                1
# Barrio Cerrado "SpringDale"                1
# La Esperanza Club de Campo                 1
# Villa San Luis                             1
# Barrio Cerrado "La Emilia"                 1
# Barrio Cerrado "Jacarandá"                 1
# Barrio Cerrado "Isla del Sol"              1
# Barrio Santa Elena - Pilar del Este        1
# Los Pingüinos Country Club                 1
# Villa Brown                                1
# Santa Juana                                1
# Barrio Cerrado Los Troncos                 1
# Barrio Cerrado La Colina                   1
# Barrio Cerrado El Casco de Alvarez         1
# Barrio Cerrado "La Chacra"                 1
# Barrio San Marco                           1
# Barrio Cerrado "La Merced"                 1
# Santa Rosa                                 1
# Barrio Cerrado "La Laguna"                 1
# Barrio Melazzi                             1
# Barrio Cerrado "Las Marías"                1
# La Matilda                                 1
# Veinte de Junio                            1
# Barrio Cerrado La Masia                    1
# Club de Campo Manuel Belgrano              1
# Name: place_name, Length: 611, dtype: int64

# %%
dsSell[['place_name', 'price_aprox_usd']]
# Out:
#                   place_name  price_aprox_usd
# 3            Villa Ballester         110000.0
# 6                 San Martín          99000.0
# 10                     Tigre         110000.0
# 11                     Pilar         650000.0
# 12                     Tigre         300000.0
# 13               Las Cañitas         600000.0
# 14                    Flores         220000.0
# 16                  Floresta          51900.0
# 17         Parque Centenario         195000.0
# 18                   Liniers         115000.0
# 19                     Tigre         195000.0
# 20              Constitución          69000.0
# 21              Constitución          61200.0
# 22                     Tigre        1100000.0
# 23                     Pilar         320000.0
# 24                  Recoleta         280000.0
# 25                  Recoleta         138500.0
# 26                     Tigre         190000.0
# 27                     Tigre         530000.0
# 28             Villa Udaondo         175000.0
# 29      San Antonio De Padua         120000.0
# 30                  Victoria          50000.0
# 31           Villa Ballester          89000.0
# 32              Villa Crespo          76500.0
# 33              Villa Crespo         127500.0
# 34                   Palermo         160000.0
# 35               Ramos Mejía          85000.0
# 36               Ramos Mejía          85000.0
# 37               Ramos Mejía          85000.0
# 38          Villa Pueyrredón         116900.0
# ...                      ...              ...
# 187403       Capital Federal         141000.0
# 187406       Capital Federal         138800.0
# 187407       Capital Federal         133000.0
# 187408       Lomas de Zamora         207000.0
# 187409       Capital Federal         135000.0
# 187410       Capital Federal         137000.0
# 187411                 Nuñez         380000.0
# 187414                Olivos         548200.0
# 187415             Temperley         162000.0
# 187416                  Boca          75000.0
# 187417               Coghlan         219000.0
# 187418                Olivos         652200.0
# 187419             Caballito         330000.0
# 187420              El Talar         225000.0
# 187423             Mataderos         150000.0
# 187424       Capital Federal          92000.0
# 187426          Barrio Norte         245000.0
# 187466      Jose Leon Suarez          80000.0
# 187468                Olivos         370000.0
# 187469            El Palomar         120000.0
# 187470       Lomas de Zamora         140000.0
# 187471              Recoleta         142000.0
# 187472              Recoleta         215000.0
# 187473               Palermo         145000.0
# 187474                Matheu         118000.0
# 187475          Barrio Norte         155000.0
# 187476         Villa Urquiza         219000.0
# 187478              Belgrano         108000.0
# 187479              Martínez         248000.0
# 187480            Villa Luro         110000.0
#
# [301820 rows x 2 columns]

# %%
aux = dsSell.groupby('place_name').mean().reset_index().sort_values(by = 'price_aprox_usd',ascending= False)[['place_name', 'price_aprox_usd']]
aux
# Out:
#                           place_name  price_aprox_usd
# 610   Área de Promoción El Triángulo     6.000000e+06
# 490                 San Isidro Chico     1.798571e+06
# 27                     Bahía del Sol     1.614286e+06
# 528                 The Boating Club     1.295000e+06
# 105                   Barrio La Isla     1.283365e+06
# 100                  Barrio El Yacht     1.061250e+06
# 201                      Club Newman     1.009333e+06
# 263              El Talar de Pacheco     9.479639e+05
# 428                Pacheco Golf Club     9.475938e+05
# 4                Abril Club de Campo     9.384138e+05
# 110              Barrio Los Castores     8.909178e+05
# 298                       Grand Bell     8.900000e+05
# 457                    Puerto Madero     8.832367e+05
# 38             Barrio Cabos del Lago     8.644444e+05
# 246               El Casco de Leloir     8.200000e+05
# 228                   Cruce Castelar     7.950000e+05
# 60     Barrio Cerrado "La Escondida"     7.690000e+05
# 471                  Rincon Del Arca     7.527273e+05
# 380       Los Pingüinos Country Club     7.500000e+05
# 11          Albanueva Barrio Cerrado     7.368462e+05
# 493                         San Juan     7.324721e+05
# 23                   Altos del Pilar     7.265455e+05
# 225        Country San Jorge Village     7.096275e+05
# 219                Country Farm Club     6.987500e+05
# 370                       Loma Verde     6.912716e+05
# 151       Barrio cerrado Camino Real     6.900000e+05
# 504     Santa Barbara Barrio Cerrado     6.874645e+05
# 601                 Virasoro Village     6.700000e+05
# 69       Barrio Cerrado "Las Marías"     6.700000e+05
# 71    Barrio Cerrado "Las Victorias"     6.666667e+05
# ..                               ...              ...
# 560                 Villa Centenario     8.566667e+04
# 571   Villa Granaderos De San Martin     8.564100e+04
# 199                         Claypole     8.492421e+04
# 377                       Los Hornos     8.427893e+04
# 395  Maria del Parque Barrio Privado     8.250000e+04
# 1                         los alamos     8.160000e+04
# 170                          Bosques     8.017511e+04
# 495                      San Lorenzo     7.922225e+04
# 319                  Ignacio Correas     7.902253e+04
# 458                    Puerto Paraná     7.666667e+04
# 365                         Libertad     7.562945e+04
# 602                  Virrey del Pino     7.183706e+04
# 553                   Villa Ayacucho     6.885714e+04
# 478                      San Alberto     6.827576e+04
# 236                         Dock Sud     6.699091e+04
# 271                       Etcheverry     6.574336e+04
# 80      Barrio Cerrado "Pilar House"     6.250000e+04
# 237                        Domselaar     6.142320e+04
# 562            Villa Coronel Zapiola     5.842650e+04
# 561                  Villa Chacabuco     5.650000e+04
# 581                   Villa Numancia     5.380679e+04
# 230                        Cuartel V     5.228735e+04
# 194                         Churruca     5.080020e+04
# 499                 San Miguel Oeste     4.911360e+04
# 297                           Gorina     4.500000e+04
# 590                   Villa San Luis     4.328513e+04
# 321             Ingeniero Juan Allan     4.251475e+04
# 239                       Don Orione     3.169860e+04
# 558                      Villa Brown     2.576496e+04
# 96        Barrio Cerrado Los Troncos     0.000000e+00
#
# [611 rows x 2 columns]

# %%
# %matplotlib notebook

numeros = list(range(0, len(aux['place_name'])))
plt.bar(numeros, aux['price_aprox_usd'])
plt.suptitle("Relación entre precio y lugar de propiedades en venta")
plt.xlabel("Lugar")
plt.ylabel("Precio")
plt.xticks(numeros, aux['place_name'])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1499.6666219731185">
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-55-ba2cafe3df21> in <module>()
#       3 numeros = list(range(0, len(aux['place_name'])))
#       4 plt.bar(numeros, aux['price_aprox_usd'])
# ----> 5 plt.suptitle("Relación entre precio y lugar de propiedades en venta")
#       6 plt.xlabel("Lugar")
#       7 plt.ylabel("Precio")
#
# C:\Users\gonza\Anaconda2\lib\site-packages\matplotlib\pyplot.pyc in suptitle(*args, **kwargs)
#     736 @docstring.copy_dedent(Figure.suptitle)
#     737 def suptitle(*args, **kwargs):
# --> 738     return gcf().suptitle(*args, **kwargs)
#     739
#     740
#
# C:\Users\gonza\Anaconda2\lib\site-packages\matplotlib\figure.pyc in suptitle(self, t, **kwargs)
#     555                 kwargs['weight'] = rcParams['figure.titleweight']
#     556
# --> 557         sup = self.text(x, y, t, **kwargs)
#     558         if self._suptitle is not None:
#     559             self._suptitle.set_text(t)
#
# C:\Users\gonza\Anaconda2\lib\site-packages\matplotlib\figure.pyc in text(self, x, y, s, *args, **kwargs)
#    1310
#    1311         override = _process_text_args({}, *args, **kwargs)
# -> 1312         t = Text(x=x, y=y, text=s)
#    1313
#    1314         t.update(override)
#
# C:\Users\gonza\Anaconda2\lib\site-packages\matplotlib\text.pyc in __init__(self, x, y, text, color, verticalalignment, horizontalalignment, multialignment, fontproperties, rotation, linespacing, rotation_mode, usetex, wrap, **kwargs)
#     219             fontproperties = FontProperties(fontproperties)
#     220
# --> 221         self.set_text(text)
#     222         self.set_color(color)
#     223         self.set_usetex(usetex)
#
# C:\Users\gonza\Anaconda2\lib\site-packages\matplotlib\text.pyc in set_text(self, s)
#    1210         ACCEPTS: string or anything printable with '%s' conversion.
#    1211         """
# -> 1212         self._text = '%s' % (s,)
#    1213         self.stale = True
#    1214
#
# UnicodeDecodeError: 'ascii' codec can't decode byte 0xc3 in position 6: ordinal not in range(128)

# %%
aux = dsSell.groupby('place_name').count().reset_index().rename(columns={'price_aprox_usd':'cantidad'}).sort_values(by = 'cantidad',ascending= False)[['place_name', 'cantidad']]
aux
# Out:
#                               place_name  cantidad
# 529                                Tigre     12115
# 421                             Nordelta     11696
# 183                      Capital Federal     11499
# 444                                Pilar     10249
# 156                             Belgrano      9505
# 464                          Ramos Mejía      9379
# 429                              Palermo      8294
# 178                            Caballito      6364
# 423                               Olivos      6311
# 417                                Morón      5211
# 489                           San Isidro      5119
# 596                        Villa Urquiza      4635
# 159                            Benavidez      4610
# 563                         Villa Crespo      4398
# 117                         Barrio Norte      4332
# 466                             Recoleta      4257
# 281                               Flores      4241
# 401                             Martínez      4208
# 306                                Haedo      4072
# 326                            Ituzaingó      4045
# 353                             La Plata      3942
# 547                        Vicente López      3845
# 15                               Almagro      3710
# 486                         San Fernando      3685
# 498                           San Miguel      3518
# 422                                Nuñez      3143
# 28                             Balvanera      3069
# 173             Bs.As. G.B.A. Zona Norte      2973
# 497                           San Martín      2900
# 372                      Lomas de Zamora      2647
# ..                                   ...       ...
# 53        Barrio Cerrado "La Candelaria"         1
# 350                           La Matilda         1
# 129      Barrio Privado Lagos de Canning         1
# 265                      El Viejo Vivero         1
# 194                             Churruca         1
# 142                     Barrio San Marco         1
# 509                           Santa Rosa         1
# 116                       Barrio Melazzi         1
# 506                          Santa Juana         1
# 147  Barrio Santa Elena - Pilar del Este         1
# 533                           Transradio         1
# 96            Barrio Cerrado Los Troncos         1
# 92               Barrio Cerrado La Masia         1
# 91              Barrio Cerrado La Colina         1
# 543                      Veinte de Junio         1
# 88    Barrio Cerrado El Casco de Alvarez         1
# 86           Barrio Cerrado "Villa Rosa"         1
# 56            Barrio Cerrado "La Chacra"         1
# 84           Barrio Cerrado "SpringDale"         1
# 205        Club de Campo Manuel Belgrano         1
# 482    San Carlos Country Club - Entrada         1
# 558                          Villa Brown         1
# 69           Barrio Cerrado "Las Marías"         1
# 66            Barrio Cerrado "La Retama"         1
# 65           Barrio Cerrado "La Reserva"         1
# 62            Barrio Cerrado "La Merced"         1
# 61            Barrio Cerrado "La Laguna"         1
# 60         Barrio Cerrado "La Escondida"         1
# 59            Barrio Cerrado "La Emilia"         1
# 610       Área de Promoción El Triángulo         1
#
# [611 rows x 2 columns]

# %%
# %matplotlib notebook

numeros = list(range(0, len(aux['place_name'])))
plt.bar(numeros, aux['cantidad'])
plt.suptitle("Relación entre lugar y cantidad de publicaciones de ese lugar")
plt.xlabel("Lugar")
plt.ylabel("Cantidad")
plt.xticks(numeros, aux['place_name'])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1499.6666219731185">
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-57-002d77470d23> in <module>()
#       3 numeros = list(range(0, len(aux['place_name'])))
#       4 plt.bar(numeros, aux['cantidad'])
# ----> 5 plt.suptitle("Relación entre lugar y cantidad de publicaciones de ese lugar")
#       6 plt.xlabel("Lugar")
#       7 plt.ylabel("Cantidad")
#
# C:\Users\gonza\Anaconda2\lib\site-packages\matplotlib\pyplot.pyc in suptitle(*args, **kwargs)
#     736 @docstring.copy_dedent(Figure.suptitle)
#     737 def suptitle(*args, **kwargs):
# --> 738     return gcf().suptitle(*args, **kwargs)
#     739
#     740
#
# C:\Users\gonza\Anaconda2\lib\site-packages\matplotlib\figure.pyc in suptitle(self, t, **kwargs)
#     555                 kwargs['weight'] = rcParams['figure.titleweight']
#     556
# --> 557         sup = self.text(x, y, t, **kwargs)
#     558         if self._suptitle is not None:
#     559             self._suptitle.set_text(t)
#
# C:\Users\gonza\Anaconda2\lib\site-packages\matplotlib\figure.pyc in text(self, x, y, s, *args, **kwargs)
#    1310
#    1311         override = _process_text_args({}, *args, **kwargs)
# -> 1312         t = Text(x=x, y=y, text=s)
#    1313
#    1314         t.update(override)
#
# C:\Users\gonza\Anaconda2\lib\site-packages\matplotlib\text.pyc in __init__(self, x, y, text, color, verticalalignment, horizontalalignment, multialignment, fontproperties, rotation, linespacing, rotation_mode, usetex, wrap, **kwargs)
#     219             fontproperties = FontProperties(fontproperties)
#     220
# --> 221         self.set_text(text)
#     222         self.set_color(color)
#     223         self.set_usetex(usetex)
#
# C:\Users\gonza\Anaconda2\lib\site-packages\matplotlib\text.pyc in set_text(self, s)
#    1210         ACCEPTS: string or anything printable with '%s' conversion.
#    1211         """
# -> 1212         self._text = '%s' % (s,)
#    1213         self.stale = True
#    1214
#
# UnicodeDecodeError: 'ascii' codec can't decode byte 0xc3 in position 6: ordinal not in range(128)

# %%
#convertimos el formato de la fecha
dsSell['year'] =pd.to_numeric(dsSell['created_on'].map( lambda x: x.split('-')[0]))
dsSell['month'] = pd.to_numeric(dsSell['created_on'].map( lambda x: x.split('-')[1]))
dsSell['created_on'] = dsSell['created_on'] .map(lambda x: x.split('-')[0]+x.split('-')[1]+x.split('-')[2])
dsSell
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-59-16580b07547e> in <module>()
#       1 #convertimos el formato de la fecha
#       2 dsSell['year'] =pd.to_numeric(dsSell['created_on'].map( lambda x: x.split('-')[0]))
# ----> 3 dsSell['month'] = pd.to_numeric(dsSell['created_on'].map( lambda x: x.split('-')[1]))
#       4 dsSell['created_on'] = dsSell['created_on'] .map(lambda x: x.split('-')[0]+x.split('-')[1]+x.split('-')[2])
#       5 dsSell
#
# C:\Users\gonza\Anaconda2\lib\site-packages\pandas\core\series.pyc in map(self, arg, na_action)
#    2156         else:
#    2157             # arg is a function
# -> 2158             new_values = map_f(values, arg)
#    2159
#    2160         return self._constructor(new_values,
#
# pandas\_libs\src\inference.pyx in pandas._libs.lib.map_infer (pandas\_libs\lib.c:66440)()
#
# <ipython-input-59-16580b07547e> in <lambda>(x)
#       1 #convertimos el formato de la fecha
#       2 dsSell['year'] =pd.to_numeric(dsSell['created_on'].map( lambda x: x.split('-')[0]))
# ----> 3 dsSell['month'] = pd.to_numeric(dsSell['created_on'].map( lambda x: x.split('-')[1]))
#       4 dsSell['created_on'] = dsSell['created_on'] .map(lambda x: x.split('-')[0]+x.split('-')[1]+x.split('-')[2])
#       5 dsSell
#
# IndexError: list index out of range

# %%
#vemos las distintas moneadas en las que se realizan las transacciones 
dsSell['currency'].value_counts()
# Out:
# USD    279287
# ARS     21725
# BRL         2
# PEN         2
# Name: currency, dtype: int64

# %%
#pasar precios a usd


#usamos un promedio aprox del dolar en estos 4 años. se peude hacer ocn mas precisión
#dsSell['priceInUsd'] = dsSell[['price', 'currency']].apply(lambda x: x[0] if x[1] == 'USD' else x[0] / 14, axis=1) 

#dsSell['priceInUsd']

# %%
#vemos como evolucionan algunos features en el tiempo para la venta
cantidadSellEnAnios = dsSell.groupby('created_on').count().reset_index().rename(columns={'price_aprox_usd':'cantidad'}).sort_values(by = 'created_on',ascending= True)[['created_on', 'cantidad']]
preciosSellEnAnios = dsSell.groupby('created_on').mean().reset_index().sort_values(by = 'created_on',ascending= True)[['created_on', 'price_aprox_usd']]

# %%
# %matplotlib notebook

numeros = list(range(0, len(cantidadSellEnAnios['created_on'])))
plt.bar(numeros, cantidadSellEnAnios['cantidad'])
plt.suptitle("Evolución de cantidad de rentas en el tiempo")
plt.xlabel("Tiempo")
plt.ylabel("Cantidad Rentas")
plt.xticks(numeros, cantidadSellEnAnios['created_on'])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1499.6666219731185">
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-63-96ccf52ec7c6> in <module>()
#       3 numeros = list(range(0, len(cantidadSellEnAnios['created_on'])))
#       4 plt.bar(numeros, cantidadSellEnAnios['cantidad'])
# ----> 5 plt.suptitle("Evolución de cantidad de rentas en el tiempo")
#       6 plt.xlabel("Tiempo")
#       7 plt.ylabel("Cantidad Rentas")
#
# C:\Users\gonza\Anaconda2\lib\site-packages\matplotlib\pyplot.pyc in suptitle(*args, **kwargs)
#     736 @docstring.copy_dedent(Figure.suptitle)
#     737 def suptitle(*args, **kwargs):
# --> 738     return gcf().suptitle(*args, **kwargs)
#     739
#     740
#
# C:\Users\gonza\Anaconda2\lib\site-packages\matplotlib\figure.pyc in suptitle(self, t, **kwargs)
#     555                 kwargs['weight'] = rcParams['figure.titleweight']
#     556
# --> 557         sup = self.text(x, y, t, **kwargs)
#     558         if self._suptitle is not None:
#     559             self._suptitle.set_text(t)
#
# C:\Users\gonza\Anaconda2\lib\site-packages\matplotlib\figure.pyc in text(self, x, y, s, *args, **kwargs)
#    1310
#    1311         override = _process_text_args({}, *args, **kwargs)
# -> 1312         t = Text(x=x, y=y, text=s)
#    1313
#    1314         t.update(override)
#
# C:\Users\gonza\Anaconda2\lib\site-packages\matplotlib\text.pyc in __init__(self, x, y, text, color, verticalalignment, horizontalalignment, multialignment, fontproperties, rotation, linespacing, rotation_mode, usetex, wrap, **kwargs)
#     219             fontproperties = FontProperties(fontproperties)
#     220
# --> 221         self.set_text(text)
#     222         self.set_color(color)
#     223         self.set_usetex(usetex)
#
# C:\Users\gonza\Anaconda2\lib\site-packages\matplotlib\text.pyc in set_text(self, s)
#    1210         ACCEPTS: string or anything printable with '%s' conversion.
#    1211         """
# -> 1212         self._text = '%s' % (s,)
#    1213         self.stale = True
#    1214
#
# UnicodeDecodeError: 'ascii' codec can't decode byte 0xc3 in position 7: ordinal not in range(128)

# %%
# %matplotlib notebook

numeros = list(range(0, len(preciosSellEnAnios['created_on'])))
plt.bar(numeros, preciosSellEnAnios['price_aprox_usd'])
plt.suptitle("Evolución del precio a lo largo del tiempo")
plt.xlabel("Tiempo")
plt.ylabel("Precio")
plt.xticks(numeros, preciosSellEnAnios['created_on'])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1499.6666219731185">
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-64-c4d3d1ccf1d0> in <module>()
#       3 numeros = list(range(0, len(preciosSellEnAnios['created_on'])))
#       4 plt.bar(numeros, preciosSellEnAnios['price_aprox_usd'])
# ----> 5 plt.suptitle("Evolución del precio a lo largo del tiempo")
#       6 plt.xlabel("Tiempo")
#       7 plt.ylabel("Precio")
#
# C:\Users\gonza\Anaconda2\lib\site-packages\matplotlib\pyplot.pyc in suptitle(*args, **kwargs)
#     736 @docstring.copy_dedent(Figure.suptitle)
#     737 def suptitle(*args, **kwargs):
# --> 738     return gcf().suptitle(*args, **kwargs)
#     739
#     740
#
# C:\Users\gonza\Anaconda2\lib\site-packages\matplotlib\figure.pyc in suptitle(self, t, **kwargs)
#     555                 kwargs['weight'] = rcParams['figure.titleweight']
#     556
# --> 557         sup = self.text(x, y, t, **kwargs)
#     558         if self._suptitle is not None:
#     559             self._suptitle.set_text(t)
#
# C:\Users\gonza\Anaconda2\lib\site-packages\matplotlib\figure.pyc in text(self, x, y, s, *args, **kwargs)
#    1310
#    1311         override = _process_text_args({}, *args, **kwargs)
# -> 1312         t = Text(x=x, y=y, text=s)
#    1313
#    1314         t.update(override)
#
# C:\Users\gonza\Anaconda2\lib\site-packages\matplotlib\text.pyc in __init__(self, x, y, text, color, verticalalignment, horizontalalignment, multialignment, fontproperties, rotation, linespacing, rotation_mode, usetex, wrap, **kwargs)
#     219             fontproperties = FontProperties(fontproperties)
#     220
# --> 221         self.set_text(text)
#     222         self.set_color(color)
#     223         self.set_usetex(usetex)
#
# C:\Users\gonza\Anaconda2\lib\site-packages\matplotlib\text.pyc in set_text(self, s)
#    1210         ACCEPTS: string or anything printable with '%s' conversion.
#    1211         """
# -> 1212         self._text = '%s' % (s,)
#    1213         self.stale = True
#    1214
#
# UnicodeDecodeError: 'ascii' codec can't decode byte 0xc3 in position 7: ordinal not in range(128)

# %%
#Cantidad de viviendas vendidas en dolares y pesos a lo largo del tiempo
cantidadSellEnAniosEnDolares = dsSell[dsSell['currency'] == 'USD'].groupby('created_on').count().reset_index().rename(columns={'price':'cantidad'}).sort_values(by = 'created_on',ascending= True)[['created_on', 'cantidad']]
cantidadSellEnAniosEnPesos = dsSell[dsSell['currency'] == 'ARS'].groupby('created_on').count().reset_index().rename(columns={'price':'cantidad'}).sort_values(by = 'created_on',ascending= True)[['created_on', 'cantidad']]

# %%
# %matplotlib notebook

numeros = list(range(0, len(cantidadSellEnAniosEnDolares['created_on'])))
plt.bar(numeros, cantidadSellEnAniosEnDolares['cantidad'])
plt.suptitle("Evolución de cantidad de rentas en el tiempo en dolares")
plt.xlabel("Tiempo")
plt.ylabel("Cantidad Rentas")
plt.xticks(numeros, cantidadSellEnAniosEnDolares['created_on'])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1499.6666219731185">
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-66-02807569e9b0> in <module>()
#       3 numeros = list(range(0, len(cantidadSellEnAniosEnDolares['created_on'])))
#       4 plt.bar(numeros, cantidadSellEnAniosEnDolares['cantidad'])
# ----> 5 plt.suptitle("Evolución de cantidad de rentas en el tiempo en dolares")
#       6 plt.xlabel("Tiempo")
#       7 plt.ylabel("Cantidad Rentas")
#
# C:\Users\gonza\Anaconda2\lib\site-packages\matplotlib\pyplot.pyc in suptitle(*args, **kwargs)
#     736 @docstring.copy_dedent(Figure.suptitle)
#     737 def suptitle(*args, **kwargs):
# --> 738     return gcf().suptitle(*args, **kwargs)
#     739
#     740
#
# C:\Users\gonza\Anaconda2\lib\site-packages\matplotlib\figure.pyc in suptitle(self, t, **kwargs)
#     555                 kwargs['weight'] = rcParams['figure.titleweight']
#     556
# --> 557         sup = self.text(x, y, t, **kwargs)
#     558         if self._suptitle is not None:
#     559             self._suptitle.set_text(t)
#
# C:\Users\gonza\Anaconda2\lib\site-packages\matplotlib\figure.pyc in text(self, x, y, s, *args, **kwargs)
#    1310
#    1311         override = _process_text_args({}, *args, **kwargs)
# -> 1312         t = Text(x=x, y=y, text=s)
#    1313
#    1314         t.update(override)
#
# C:\Users\gonza\Anaconda2\lib\site-packages\matplotlib\text.pyc in __init__(self, x, y, text, color, verticalalignment, horizontalalignment, multialignment, fontproperties, rotation, linespacing, rotation_mode, usetex, wrap, **kwargs)
#     219             fontproperties = FontProperties(fontproperties)
#     220
# --> 221         self.set_text(text)
#     222         self.set_color(color)
#     223         self.set_usetex(usetex)
#
# C:\Users\gonza\Anaconda2\lib\site-packages\matplotlib\text.pyc in set_text(self, s)
#    1210         ACCEPTS: string or anything printable with '%s' conversion.
#    1211         """
# -> 1212         self._text = '%s' % (s,)
#    1213         self.stale = True
#    1214
#
# UnicodeDecodeError: 'ascii' codec can't decode byte 0xc3 in position 7: ordinal not in range(128)

# %%
# %matplotlib notebook

numeros = list(range(0, len(cantidadSellEnAniosEnPesos['created_on'])))
plt.bar(numeros, cantidadSellEnAniosEnPesos['cantidad'])
plt.suptitle("Evolución de cantidad de rentas en el tiempo en pesos")
plt.xlabel("Tiempo")
plt.ylabel("Cantidad Rentas")
plt.xticks(numeros, cantidadSellEnAniosEnPesos['created_on'])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1499.6666219731185">
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-67-fb7ece552778> in <module>()
#       3 numeros = list(range(0, len(cantidadSellEnAniosEnPesos['created_on'])))
#       4 plt.bar(numeros, cantidadSellEnAniosEnPesos['cantidad'])
# ----> 5 plt.suptitle("Evolución de cantidad de rentas en el tiempo en pesos")
#       6 plt.xlabel("Tiempo")
#       7 plt.ylabel("Cantidad Rentas")
#
# C:\Users\gonza\Anaconda2\lib\site-packages\matplotlib\pyplot.pyc in suptitle(*args, **kwargs)
#     736 @docstring.copy_dedent(Figure.suptitle)
#     737 def suptitle(*args, **kwargs):
# --> 738     return gcf().suptitle(*args, **kwargs)
#     739
#     740
#
# C:\Users\gonza\Anaconda2\lib\site-packages\matplotlib\figure.pyc in suptitle(self, t, **kwargs)
#     555                 kwargs['weight'] = rcParams['figure.titleweight']
#     556
# --> 557         sup = self.text(x, y, t, **kwargs)
#     558         if self._suptitle is not None:
#     559             self._suptitle.set_text(t)
#
# C:\Users\gonza\Anaconda2\lib\site-packages\matplotlib\figure.pyc in text(self, x, y, s, *args, **kwargs)
#    1310
#    1311         override = _process_text_args({}, *args, **kwargs)
# -> 1312         t = Text(x=x, y=y, text=s)
#    1313
#    1314         t.update(override)
#
# C:\Users\gonza\Anaconda2\lib\site-packages\matplotlib\text.pyc in __init__(self, x, y, text, color, verticalalignment, horizontalalignment, multialignment, fontproperties, rotation, linespacing, rotation_mode, usetex, wrap, **kwargs)
#     219             fontproperties = FontProperties(fontproperties)
#     220
# --> 221         self.set_text(text)
#     222         self.set_color(color)
#     223         self.set_usetex(usetex)
#
# C:\Users\gonza\Anaconda2\lib\site-packages\matplotlib\text.pyc in set_text(self, s)
#    1210         ACCEPTS: string or anything printable with '%s' conversion.
#    1211         """
# -> 1212         self._text = '%s' % (s,)
#    1213         self.stale = True
#    1214
#
# UnicodeDecodeError: 'ascii' codec can't decode byte 0xc3 in position 7: ordinal not in range(128)

# %%
#analizamos el precio de los lugares a lo largo del tiempo

aux = dsSell.groupby(['place_name', 'created_on']).mean().reset_index().sort_values(by = 'price_aprox_usd',ascending= False)[['place_name', 'created_on','price_aprox_usd']]
aux

# %%
#ESTO ESTA BASTATNE MAL 


# %matplotlib notebook

plt.scatter(aux['created_on'], aux['price_aprox_usd'])
plt.suptitle("Evolución de preico en pesos en los lugares a lo largo del tiempo")
plt.xlabel("Tiempo")
plt.ylabel("Precio En Pesos")
#plt.xticks(numeros, cantidadRentEnAniosEnPesos['created_on'])
plt.show()

# %%
#Vemos que zona tiene mas propiedades vendidas
# %matplotlib notebook
nombre_zona = ['CABA', 'Zona Norte', 'Zona Oeste', 'Zona Sur']
cosa = [1, 2, 3, 4]
cant = dsSell['zona'].value_counts()
precios_zona = [cant[0], cant[1], cant[2], cant[3]]
plt.bar(cosa, precios_zona)
plt.suptitle("Cantidad de propiedades vendidas por zona")
plt.xlabel("Nombre de la zona")
plt.ylabel("Cantidad de propiedades")
plt.xticks(cosa, nombre_zona)
# Out:
# <img src="data:image/png;base64,..." width="1499.6666219731185">
# ([<matplotlib.axis.XTick at 0x99affd30>,
#   <matplotlib.axis.XTick at 0x99b0b390>,
#   <matplotlib.axis.XTick at 0x99b52208>,
#   <matplotlib.axis.XTick at 0x99b71080>],
#  <a list of 4 Text xticklabel objects>)

# %%
#Calculamos que tipo de propiedad se vende mas en Zona Norte
# %matplotlib notebook
nombre_zona = ['house', 'apartment', 'PH', 'store']
cosa = [1, 2, 3, 4]
typ = dsSell[dsSell.zona == 'Bs.As. G.B.A. Zona Norte']['property_type'].value_counts()
precios_zona = [typ[0], typ[1], typ[2], typ[3]]
plt.bar(cosa, precios_zona)
plt.suptitle("Cantidad de propiedades por tipo en Zona Norte")
plt.xlabel("Tipo de propiedad")
plt.ylabel("Cantidad de propiedades")
plt.xticks(cosa, nombre_zona)
# Out:
# <img src="data:image/png;base64,..." width="1499.6666219731185">
# ([<matplotlib.axis.XTick at 0x99b97860>,
#   <matplotlib.axis.XTick at 0x99ba4390>,
#   <matplotlib.axis.XTick at 0x99d2e198>,
#   <matplotlib.axis.XTick at 0x99dc1f98>],
#  <a list of 4 Text xticklabel objects>)

# %%
#Calculamos que tipo de propiedad se vende mas en Zona Sur
# %matplotlib notebook
nombre_zona = ['house', 'apartment', 'PH', 'store']
cosa = [1, 2, 3, 4]
typ = dsSell[dsSell.zona == 'Bs.As. G.B.A. Zona Sur']['property_type'].value_counts()
precios_zona = [typ[0], typ[1], typ[2], typ[3]]
plt.bar(cosa, precios_zona)
plt.suptitle("Cantidad de propiedades por tipo en Zona Sur")
plt.xlabel("Tipo de propiedad")
plt.ylabel("Cantidad de propiedades")
plt.xticks(cosa, nombre_zona)
# Out:
# <img src="data:image/png;base64,..." width="1499.6666219731185">
# ([<matplotlib.axis.XTick at 0x99bf3898>,
#   <matplotlib.axis.XTick at 0x99bff438>,
#   <matplotlib.axis.XTick at 0x99c8c240>,
#   <matplotlib.axis.XTick at 0x99ca8080>],
#  <a list of 4 Text xticklabel objects>)

# %%
#Calculamos que tipo de propiedad se vende mas en Zona Oeste
# %matplotlib notebook
nombre_zona = ['apartment', 'house', 'PH', 'store']
cosa = [1, 2, 3, 4]
aux = dsSell[dsSell.zona == 'Bs.As. G.B.A. Zona Oeste']
typ = aux.groupby('property_type').mean()['price_aprox_usd']
precios_zona = [typ[0], typ[1], typ[2], typ[3]]
plt.bar(cosa, precios_zona)
plt.suptitle("Costo promedio por tipo")
plt.xlabel("Tipo de propiedad")
plt.ylabel("Costo promedio")
plt.xticks(cosa, nombre_zona)
# Out:
# <img src="data:image/png;base64,..." width="1499.6666219731185">
# ([<matplotlib.axis.XTick at 0x9a15d1d0>,
#   <matplotlib.axis.XTick at 0x99ffd438>,
#   <matplotlib.axis.XTick at 0x9a6c02b0>,
#   <matplotlib.axis.XTick at 0x9a6dd128>],
#  <a list of 4 Text xticklabel objects>)

# %%
#Calculamos que tipo de propiedad se vende mas en Capital Federal
# %matplotlib notebook
nombre_zona = ['apartment', 'house', 'PH', 'store']
cosa = [1, 2, 3, 4]
typ = dsSell[dsSell.zona == 'Capital Federal']['property_type'].value_counts()
precios_zona = [typ[0], typ[1], typ[2], typ[3]]
plt.bar(cosa, precios_zona)
plt.suptitle("Cantidad de propiedades por tipo en Capital Federal")
plt.xlabel("Tipo de propiedad")
plt.ylabel("Cantidad de propiedades")
plt.xticks(cosa, nombre_zona)
# Out:
# <img src="data:image/png;base64,..." width="1499.6666219731185">
# ([<matplotlib.axis.XTick at 0x99e88a20>,
#   <matplotlib.axis.XTick at 0x998ad6d8>,
#   <matplotlib.axis.XTick at 0x9a10aeb8>,
#   <matplotlib.axis.XTick at 0x9a127cf8>],
#  <a list of 4 Text xticklabel objects>)

# %%
#Calculamos cuanto sale cada tipo en promedio en Capital Federal
# %matplotlib notebook
nombre_zona = ['apartment', 'house', 'PH', 'store']
cosa = [1, 2, 3, 4]
typ = dsSell[dsSell.zona == 'Capital Federal']['price_aprox_usd'].value_counts()
precios_zona = [typ[0], typ[1], typ[2], typ[3]]
plt.bar(cosa, precios_zona)
plt.suptitle("Cantidad de propiedades por tipo en Capital Federal")
plt.xlabel("Tipo de propiedad")
plt.ylabel("Cantidad de propiedades")
plt.xticks(cosa, nombre_zona)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-85-8a9e196659b1> in <module>()
#       4 cosa = [1, 2, 3, 4]
#       5 typ = dsSell[dsSell.zona == 'Capital Federal']['price_aprox_usd'].value_counts()
# ----> 6 precios_zona = [typ[0], typ[1], typ[2], typ[3]]
#       7 plt.bar(cosa, precios_zona)
#       8 plt.suptitle("Cantidad de propiedades por tipo en Capital Federal")
#
# C:\Users\gonza\Anaconda2\lib\site-packages\pandas\core\series.pyc in __getitem__(self, key)
#     599         key = com._apply_if_callable(key, self)
#     600         try:
# --> 601             result = self.index.get_value(self, key)
#     602
#     603             if not is_scalar(result):
#
# C:\Users\gonza\Anaconda2\lib\site-packages\pandas\core\indexes\numeric.pyc in get_value(self, series, key)
#     317
#     318         k = _values_from_object(key)
# --> 319         loc = self.get_loc(k)
#     320         new_values = _values_from_object(series)[loc]
#     321
#
# C:\Users\gonza\Anaconda2\lib\site-packages\pandas\core\indexes\numeric.pyc in get_loc(self, key, method, tolerance)
#     374             pass
#     375         return super(Float64Index, self).get_loc(key, method=method,
# --> 376                                                  tolerance=tolerance)
#     377
#     378     @cache_readonly
#
# C:\Users\gonza\Anaconda2\lib\site-packages\pandas\core\indexes\base.pyc in get_loc(self, key, method, tolerance)
#    2393                 return self._engine.get_loc(key)
#    2394             except KeyError:
# -> 2395                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2396
#    2397         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5239)()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5085)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Float64HashTable.get_item (pandas\_libs\hashtable.c:7353)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Float64HashTable.get_item (pandas\_libs\hashtable.c:7297)()
#
# KeyError: 1.0

# %%
#Calculamos cuanto sale cada tipo en promedio 
# %matplotlib notebook
nombre_zona = ['PH', 'apartment', 'house', 'store']
cosa = [1, 2, 3, 4]
typ = dsSell.groupby('property_type').mean()['price_aprox_usd']
precios_zona = [typ[0], typ[1], typ[2], typ[3]]
plt.bar(cosa, precios_zona)
plt.suptitle("Costo promedio por tipo")
plt.xlabel("Tipo de propiedad")
plt.ylabel("Costo promedio")
plt.xticks(cosa, nombre_zona)
# Out:
# <img src="data:image/png;base64,..." width="1499.6666219731185">
# ([<matplotlib.axis.XTick at 0x9a580668>,
#   <matplotlib.axis.XTick at 0x9a5e5ac8>,
#   <matplotlib.axis.XTick at 0x9a76d8d0>,
#   <matplotlib.axis.XTick at 0x9a788748>],
#  <a list of 4 Text xticklabel objects>)

# %%
#Vemos que zona es mas cara en promedio
# %matplotlib notebook
nombre_zona = ['Zona Norte', 'Zona Oeste', 'Zona Sur', 'Capital Federal']
cosa = [1, 2, 3, 4]
typ = dsSell.groupby('zona').mean()['price_aprox_usd']
precios_zona = [typ[0], typ[1], typ[2], typ[3]]
plt.bar(cosa, precios_zona)
plt.suptitle("Costo promedio por zona")
plt.xlabel("Zona")
plt.ylabel("Costo promedio")
plt.xticks(cosa, nombre_zona)
# Out:
# <img src="data:image/png;base64,..." width="1499.6666219731185">
# ([<matplotlib.axis.XTick at 0x9a580b70>,
#   <matplotlib.axis.XTick at 0x9aaac978>,
#   <matplotlib.axis.XTick at 0x9aaf47f0>,
#   <matplotlib.axis.XTick at 0x9ab0f5c0>],
#  <a list of 4 Text xticklabel objects>)

# %%
#Que cantidad de ambientes se vende mas?
# %matplotlib notebook
cosa = [2, 3, 1, 4, 5]
typ = dsSell['rooms'].value_counts()
precios_piso = [typ[2], typ[3], typ[1], typ[4], typ[5]]
plt.bar(cosa, precios_piso)
plt.title('Top 5 de propiedades vendidas por cantidad de ambientes')
plt.xlabel('Numero de ambientes')
plt.ylabel('Cantidad de propiedades vendidas')
# Out:
# <img src="data:image/png;base64,..." width="1499.6666219731185">

# %%
#Caculamos la superficie promedio de cada tipo de propiedad
# %matplotlib notebook
cosa = [1, 2, 3, 4]
nombre_tipo=['house', 'apartment', 'house', 'store']
typ = dsSell.groupby('property_type').mean()['surface_in_m2']
precios_zona = [typ[0], typ[1], typ[2], typ[3]]
plt.bar(cosa, precios_zona)
plt.suptitle("Superficia promedio por tipo de propiedad")
plt.xlabel("Tipo de propiedad")
plt.ylabel("Superficie promedio")
plt.xticks(cosa, nombre_tipo)
# Out:
# <img src="data:image/png;base64,..." width="1499.6666219731185">
# ([<matplotlib.axis.XTick at 0x9a580518>,
#   <matplotlib.axis.XTick at 0x9ac68b00>,
#   <matplotlib.axis.XTick at 0x9acf1908>,
#   <matplotlib.axis.XTick at 0x9ad0e748>],
#  <a list of 4 Text xticklabel objects>)

# %%
dsSell.groupby('zona').mean()['price_usd_per_m2']
# Out:
# zona
# Bs.As. G.B.A. Zona Norte    1610.989222
# Bs.As. G.B.A. Zona Oeste    1327.090048
# Bs.As. G.B.A. Zona Sur      1398.366268
# Capital Federal             2641.700734
# Name: price_usd_per_m2, dtype: float64

# %%
Sell2012 = dsSell[dsSell.created_on.str.contains('2012')]
Sell2013 = dsSell[dsSell.created_on.str.contains('2013')]
Sell2014 = dsSell[dsSell.created_on.str.contains('2014')]
Sell2015 = dsSell[dsSell.created_on.str.contains('2015')]
Sell2016 = dsSell[dsSell.created_on.str.contains('2016')]
Sell2017 = dsSell[dsSell.created_on.str.contains('2017')]
print (Sell2012.id.count())
print (Sell2013.id.count())
print (Sell2014.id.count())
print (Sell2015.id.count())
print (Sell2016.id.count())
print (Sell2017.id.count())
# Out:
# 3
# 357
# 3599
# 8315
# 59443
# 76030

# %%
dSell2012 = Sell2012.groupby('zona').mean().reset_index()[['zona','price_usd_per_m2']]
dSell2013 = Sell2013.groupby('zona').mean().reset_index()[['zona','price_usd_per_m2']]
dSell2014 = Sell2014.groupby('zona').mean().reset_index()[['zona','price_usd_per_m2']]
dSell2015 = Sell2015.groupby('zona').mean().reset_index()[['zona','price_usd_per_m2']]
dSell2016 = Sell2016.groupby('zona').mean().reset_index()[['zona','price_usd_per_m2']]
dSell2017 = Sell2017.groupby('zona').mean().reset_index()[['zona','price_usd_per_m2']]
dSell_price_m2_per_year = Sell2012.groupby('zona').mean().reset_index()[['zona','price_usd_per_m2']]
dSell_price_m2_per_year['price_usd_per_m2-2013'] = dSell2013['price_usd_per_m2']
dSell_price_m2_per_year['price_usd_per_m2-2014'] = dSell2014['price_usd_per_m2']
dSell_price_m2_per_year['price_usd_per_m2-2015'] = dSell2015['price_usd_per_m2']
dSell_price_m2_per_year['price_usd_per_m2-2016'] = dSell2016['price_usd_per_m2']
dSell_price_m2_per_year['price_usd_per_m2-2017'] = dSell2017['price_usd_per_m2']
dSell_price_m2_per_year.rename(columns={'price_usd_per_m2':'price_usd_per_m2-2012'},inplace = True)
dSell_price_m2_per_year.head()
# Out:
#                        zona  price_usd_per_m2-2012  price_usd_per_m2-2013  \
# 0  Bs.As. G.B.A. Zona Norte            1381.806414            1851.048579
# 1  Bs.As. G.B.A. Zona Oeste             805.626271            1463.920457
# 2    Bs.As. G.B.A. Zona Sur            1206.732371            1500.689534
# 3           Capital Federal            2115.121019            2509.180265
#
#    price_usd_per_m2-2014  price_usd_per_m2-2015  price_usd_per_m2-2016  \
# 0            1211.650669            1403.292299            1634.885487
# 1            1185.779292            1282.050329            1431.704285
# 2            1191.057100            1233.497276            1343.147175
# 3            2193.455416            2457.443527            2587.740926
#
#    price_usd_per_m2-2017
# 0            1847.432807
# 1            1295.971166
# 2            1512.130051
# 3            3091.645588

# %%
per_m2 = dsSell.loc[:,['zona','price_usd_per_m2','created_on','property_type', 'year', 'month']]
per_m2['created_on'] = pd.to_numeric(per_m2['created_on'])
per_m2.head()
# Out:
#                         zona  price_usd_per_m2  created_on property_type  \
# 3   Bs.As. G.B.A. Zona Norte        315.186246    20120808         house
# 6   Bs.As. G.B.A. Zona Norte        647.058824    20120808         house
# 10  Bs.As. G.B.A. Zona Norte       1294.117647    20120808     apartment
# 11  Bs.As. G.B.A. Zona Norte       1697.127937    20120808         house
# 12  Bs.As. G.B.A. Zona Norte       1176.470588    20120808         house
#
#         year  month
# 3   20120808      8
# 6   20120808      8
# 10  20120808      8
# 11  20120808      8
# 12  20120808      8

# %%
per_m2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 301820 entries, 3 to 187480
# Data columns (total 6 columns):
# zona                301820 non-null object
# price_usd_per_m2    210223 non-null float64
# created_on          301820 non-null int64
# property_type       301820 non-null object
# year                301820 non-null int64
# month               301820 non-null int64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 16.1+ MB

# %%
indice = per_m2['zona'].value_counts().reset_index()['index']

# %%
# %matplotlib inline

plt.figure()
plt.title('Evolucion del precio promedio del m2 en USD de las propiedades entre el año 2012 - 2017')

for i in indice:
    per_m2.loc[per_m2.zona.str.contains(i),['price_usd_per_m2','year']].groupby('year').mean().loc[:,'price_usd_per_m2'].plot(linewidth=2,figsize=(6,6),label=i);
plt.ylabel('precio promedio del m2 en USD')
plt.xlabel('year')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-97-f5b2facfbbd6> in <module>()
#       2
#       3 plt.figure()
# ----> 4 plt.title('Evolucion del precio promedio del m2 en USD de las propiedades entre el año 2012 - 2017')
#       5
#       6 for i in indice:
#
# C:\Users\gonza\Anaconda2\lib\site-packages\matplotlib\pyplot.pyc in title(s, *args, **kwargs)
#    1463
#    1464     """
# -> 1465     return gca().set_title(s, *args, **kwargs)
#    1466
#    1467 ## Axis ##
#
# C:\Users\gonza\Anaconda2\lib\site-packages\matplotlib\axes\_axes.pyc in set_title(self, label, fontdict, loc, **kwargs)
#     184             'verticalalignment': 'baseline',
#     185             'horizontalalignment': loc.lower()}
# --> 186         title.set_text(label)
#     187         title.update(default)
#     188         if fontdict is not None:
#
# C:\Users\gonza\Anaconda2\lib\site-packages\matplotlib\text.pyc in set_text(self, s)
#    1210         ACCEPTS: string or anything printable with '%s' conversion.
#    1211         """
# -> 1212         self._text = '%s' % (s,)
#    1213         self.stale = True
#    1214
#
# UnicodeDecodeError: 'ascii' codec can't decode byte 0xc3 in position 73: ordinal not in range(128)

# %%
marker_size=5
plt.scatter(per_m2['created_on'], per_m2['price_usd_per_m2'],s = 50,alpha=0.25,zorder=50)
plt.suptitle("Evolución de precio del m2 en USD en los lugares a lo largo del tiempo")
plt.xlabel("Tiempo")
plt.ylabel("Precio m2en USD")
plt.xlim([min(per_m2['created_on'])- 1000 , max(per_m2['created_on'])+1000])
plt.ylim([min(per_m2['price_usd_per_m2']), max(per_m2['price_usd_per_m2'] )- 1200000])
plt.show()

# %%
# %matplotlib inline

plt.figure()
plt.title('Evolucion del precio promedio del m2 en USD de las propiedades por meses')
for i in indice:
    
    per_m2.groupby('zona').get_group(i).loc[:,['zona','price_usd_per_m2','month']].groupby('month').mean().loc[:,'price_usd_per_m2'].plot(figsize=(10,10),label=i);
plt.ylabel('precio promedio del m2 en USD')
plt.xlabel('month')
plt.legend()
plt.show()

# %%
indiceType = per_m2['property_type'].value_counts().reset_index()['index']
indiceType

# %%
# %matplotlib inline


for a in indice:
    plt.figure()
    
    for i in indiceType:
        plt.title('Evolucion del precio promedio del m2 en USD de las propiedades en la zona de '+a)
        per_m2.groupby('zona').get_group(a).groupby('property_type').get_group(i).loc[:,['zona','price_usd_per_m2','year']].groupby('year').mean().loc[:,'price_usd_per_m2'].plot(figsize=(10,10),label=i);
    plt.ylabel('precio promedio del m2 en USD')
    plt.xlabel('year')
    plt.legend()
    plt.show()

# %%
dsSell.groupby('expenses').mean()

# %%
cantidadEnVentaPorMes = dsSell.groupby(['month', 'year']).count().reset_index().rename(columns={'priceInUsd':'cantidad'})[['year', 'month', 'cantidad']]
precioEnEventaPorMes = dsSell.groupby(['month', 'year']).mean().reset_index()[['year', 'month', 'priceInUsd']]

# %%
anios = dsSell['year'].value_counts().reset_index()['index']
anios

# %%
# %matplotlib inline

plt.figure()
plt.title('Cantidad de viviendas en venta en meses para cada año')
for i in anios:
    
    cantidadEnVentaPorMes.groupby('year').get_group(i).groupby('month').mean().loc[:,'cantidad'].plot(figsize=(10,10),label=i);
plt.ylabel('Cantdad en venta')
plt.xlabel('Mes')
plt.legend()
plt.show()

# %%
# %matplotlib inline

plt.figure()
plt.title('Precio de viviendas en venta en meses para cada año')
for i in anios:
    
    precioEnEventaPorMes.groupby('year').get_group(i).groupby('month').mean().loc[:,'priceInUsd'].plot(figsize=(10,10),label=i);
plt.ylabel('Precio de venta')
plt.xlabel('Mes')
plt.legend()
plt.show()

# %%
#sobre esto tal vez se puede hacer analisis de texto. tambien analizar la imagen..
dsSell[['description', 'image_thumbnail']]

# %%
#drop de columnas

dsSell.drop('currency', axis=1, inplace=True)
dsSell.drop('extra', axis=1, inplace=True)
dsSell.drop('id', axis=1, inplace=True)
dsSell.drop('image_thumbnail', axis=1, inplace=True)
dsSell.drop('properati_url', axis=1, inplace=True)
dsSell.drop('title', axis=1, inplace=True)
dsSell.drop('lat-lon', axis=1, inplace=True)
dsSell.drop('operation', axis=1, inplace=True)
dsSell.drop('price_aprox_usd', axis=1, inplace=True)
dsSell.drop('price', axis=1, inplace=True)
dsSell.drop('price_aprox_local_currency', axis=1, inplace=True)
dsSell.drop('country_name', axis=1, inplace=True)

# %%
#one hot encoding de los place name. me suena mal muchas columnas. performance

one_hot = pd.get_dummies(dsSell['place_name'])
dsSell.drop('place_name', axis=1, inplace=True)
dsSell = dsSell.join(one_hot)

# %%
dsSell.columns
