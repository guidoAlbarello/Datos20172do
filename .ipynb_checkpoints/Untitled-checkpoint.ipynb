# %%
import datetime as datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('default') # Make the graphs a bit prettier
plt.rcParams['figure.figsize'] = (15, 5)

#ver relaciones entre datos. que datos depende de otros. cuales son redundantes y no aportan informacion.

# %%
dsRent2013 = pd.read_csv("rent2013.csv", low_memory=False)
dsSell2013 = pd.read_csv("sell2013.csv", low_memory=False)
dsRent2014 = pd.read_csv("rent2014.csv", low_memory=False)
dsSell2014 = pd.read_csv("sell2014.csv", low_memory=False)
dsRent2015 = pd.read_csv("rent2015.csv", low_memory=False)
dsSell2015 = pd.read_csv("sell2015.csv", low_memory=False)
dsRent2016 = pd.read_csv("rent2016.csv", low_memory=False)
dsSell2016 = pd.read_csv("sell2016.csv", low_memory=False)
dsRent2017 = pd.read_csv("rent2017.csv", low_memory=False)
dsSell2017 = pd.read_csv("sell2017.csv", low_memory=False)

# %%
dsRent2013.head()
# Out:
#    created_on operation property_type         place_name  \
# 0  2012-09-19      rent         house              Pilar
# 1  2012-09-27      rent     apartment            Palermo
# 2  2012-10-10      rent     apartment      Puerto Madero
# 3  2012-10-10      rent         house              Tigre
# 4  2012-10-10      rent         house  Palermo Hollywood
#
#                              place_with_parent_names  geonames_id  \
# 0   |Argentina|Bs.As. G.B.A. Zona Norte|Pilar|Pilar|          NaN
# 1                |Argentina|Capital Federal|Palermo|    3430234.0
# 2          |Argentina|Capital Federal|Puerto Madero|    3429760.0
# 3   |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|Tigre|          NaN
# 4  |Argentina|Capital Federal|Palermo|Palermo Hol...          NaN
#
#                  lat-lon        lat        lon    price currency  \
# 0                    NaN        NaN        NaN  21000.0      ARS
# 1  -34.576888,-58.423476 -34.576888 -58.423476  15000.0      ARS
# 2  -34.609439,-58.362846 -34.609439 -58.362846  25000.0      ARS
# 3                    NaN        NaN        NaN  22000.0      ARS
# 4  -34.579306,-58.434735 -34.579306 -58.434735  15000.0      ARS
#
#    price_aprox_local_currency  price_aprox_usd  surface_in_m2  \
# 0                    20999.97          3556.01          230.0
# 1                    14999.99          2540.01          120.0
# 2                    24999.99          4233.35          200.0
# 3                    21999.95          3725.34          350.0
# 4                    14999.99          2540.01          195.0
#
#    price_usd_per_m2  floor  rooms expenses  \
# 0         15.460913    NaN    NaN      NaN
# 1         21.166750    9.0    4.0     2500
# 2         21.166750   14.0    4.0      NaN
# 3         10.643829    NaN    NaN      NaN
# 4         13.025692    NaN    4.0      NaN
#
#                                        properati_url  \
# 0  http://www.properati.com.ar/u86_alquiler_casa_...
# 1  http://www.properati.com.ar/w7u_alquiler_depar...
# 2  http://www.properati.com.ar/13kc_alquiler_depa...
# 3  http://www.properati.com.ar/148s_alquiler_casa...
# 4  http://www.properati.com.ar/14cc_alquiler_casa...
#
#                                      image_thumbnail
# 0  http://cf-thumbs.properati.com.ar/diH5XHckfc0t...
# 1  http://cf-thumbs.properati.com.ar/esk2qFDd1keI...
# 2  http://cf-thumbs.properati.com.ar/ZGH-kBypKFhg...
# 3  http://cf-thumbs.properati.com.ar/RNF8bdTcX1fG...
# 4  http://cf-thumbs.properati.com.ar/VkCbplU9RvP9...

# %%
dsSell2014.columns
# Out:
# Index(['created_on', 'operation', 'property_type', 'place_name',
#        'place_with_parent_names', 'geonames_id', 'lat-lon', 'lat', 'lon',
#        'price', 'currency', 'price_aprox_local_currency', 'price_aprox_usd',
#        'surface_in_m2', 'price_usd_per_m2', 'floor', 'rooms', 'expenses',
#        'properati_url', 'image_thumbnail'],
#       dtype='object')

# %%
dsSell2015.columns
# Out:
# Index(['created_on', 'operation', 'property_type', 'place_name',
#        'place_with_parent_names', 'geonames_id', 'lat-lon', 'lat', 'lon',
#        'price', 'currency', 'price_aprox_local_currency', 'price_aprox_usd',
#        'surface_total_in_m2', 'surface_covered_in_m2', 'price_usd_per_m2',
#        'price_per_m2', 'floor', 'rooms', 'expenses', 'properati_url',
#        'description', 'title', 'extra', 'image_thumbnail'],
#       dtype='object')

# %%
dsRent = dsRent2013.append(dsRent2014).append(dsRent2015).append(dsRent2016).append(dsRent2017)
dsSell = dsSell2013.append(dsSell2014).append(dsSell2015).append(dsSell2016).append(dsSell2017)

dsRent.drop('country_name', axis=1, inplace=True)
dsSell.drop('country_name', axis=1, inplace=True)

# %%
dsSell.columns
# Out:
# Index(['created_on', 'currency', 'description', 'expenses', 'extra', 'floor',
#        'geonames_id', 'id', 'image_thumbnail', 'lat', 'lat-lon', 'lon',
#        'operation', 'place_name', 'place_with_parent_names', 'price',
#        'price_aprox_local_currency', 'price_aprox_usd', 'price_per_m2',
#        'price_usd_per_m2', 'properati_url', 'property_type', 'rooms',
#        'state_name', 'surface_covered_in_m2', 'surface_in_m2',
#        'surface_total_in_m2', 'title'],
#       dtype='object')

# %%
#cuantos tipos de vivienda se vende

dsSell['property_type'].value_counts()
# Out:
# apartment    286273
# house        176036
# PH            27935
# store         13906
# Name: property_type, dtype: int64

# %%
dsRent['property_type'].value_counts()
# Out:
# apartment    64937
# house        31558
# store        12933
# PH            2200
# Name: property_type, dtype: int64

# %%
#lugares donde mas se vende
dsSell['place_name'].value_counts()
# Out:
# Mar del Plata                  39293
# Córdoba                        19935
# Rosario                        19812
# Tigre                          12673
# Capital Federal                12652
# Ramos Mejía                    12649
# Nordelta                       12314
# Pilar                          10824
# Belgrano                       10758
# Palermo                         9631
# Punta del Este                  9299
# La Plata                        7993
# Caballito                       7147
# Olivos                          6418
# Ituzaingó                       6188
# Morón                           6156
# Pinamar                         5737
# San Isidro                      5258
# Villa Urquiza                   5152
# Haedo                           5114
# Santa Fe                        4995
# Villa Crespo                    4992
# Barrio Norte                    4847
# Flores                          4824
# Recoleta                        4703
# Benavidez                       4619
# Martínez                        4293
# San Miguel                      4278
# Almagro                         4147
# Vicente López                   4139
#                                ...
# Balneario Sauce Grande             1
# Barrio Cerrado "La Chacra"         1
# General Lavalle                    1
# Gaiman                             1
# Barrio Cerrado "SpringDale"        1
# Pablo Acosta                       1
# Estacion Chapadmalal               1
# Laguna Larga                       1
# Sierras Bayas                      1
# Barrio Cerrado "Villa Rosa"        1
# María Grande                       1
# Barrio Cerrado "Las Marías"        1
# La Esperanza Club de Campo         1
# Perú                               1
# Lago Epuyén                        1
# Batán                              1
# Díaz                               1
# Bowen                              1
# Uspallata                          1
# Quequén                            1
# La Viña                            1
#  los alamos                        1
# Barrio Cerrado "La Reserva"        1
# Benito Juárez                      1
# Valle de Anisacate                 1
# Rancagua                           1
# Barrio San Marco                   1
# Veinte de Junio                    1
# Churruca                           1
# Los Pozos                          1
# Name: place_name, dtype: int64

# %%
dsRent['place_name'].value_counts()
# Out:
# Punta del Este                           28461
# Mar del Plata                             5274
# Roosevelt                                 4169
# Pinamar                                   2523
# Nordelta                                  2427
# Palermo                                   2152
# Córdoba                                   2152
# Belgrano                                  2047
# Pilar                                     1973
# La Barra                                  1954
# Capital Federal                           1921
# Rosario                                   1849
# Manantiales                               1820
# Recoleta                                  1676
# Tigre                                     1514
# Barrio Norte                              1497
# Puerto Madero                             1429
# Montoya                                   1404
# San Rafael                                1249
# La Plata                                  1233
# Maldonado                                 1187
# Ramos Mejía                                992
# San Isidro                                 915
# Martínez                                   806
# Olivos                                     723
# San Miguel                                 721
# Punta Ballena                              711
# Posadas                                    710
# Caballito                                  694
# Palermo Chico                              693
#                                          ...
# Country Maschwitz Privado                    1
# Barrio Cerrado "La Delfina"                  1
# Mar de Cobo                                  1
# Barrio Norte - Municipio General Roca        1
# La Granja                                    1
# Punta Iglesia                                1
# Ciudad Del Libertador                        1
# Barrio Cerrado El Lauquén                    1
# Huerta Grande                                1
# Alto da Lapa                                 1
# Pilar Green Park                             1
# Burruyacú                                    1
# Barrio Privado La Campiña                    1
# Chivilcoy                                    1
# Mi Refugio                                   1
# Altos de Hudson I                            1
# Bosque Peralta Ramos                         1
# Country Sociedad Hebraica Argentina          1
# Romang                                       1
# Barrio El Jardín                             1
# Barrio Cerrado Las Casuarinas                1
# Altos del Golf                               1
# Chacras de Coria                             1
# El Retiro                                    1
# Jardim Marajoara                             1
# Cruz del Eje                                 1
# Bahía del Sol                                1
# El Dorado                                    1
# Treinta de Agosto                            1
# Coronel Pringles                             1
# Name: place_name, dtype: int64

# %%
dsSell[['place_name', 'price']]
# Out:
#                      place_name      price
# 0                      Belgrano        NaN
# 1               Villa Ballester        NaN
# 2               Villa Ballester        NaN
# 3               Villa Ballester   110000.0
# 4                  Loma Hermosa        NaN
# 5               Villa Ballester        NaN
# 6                    San Martín    99000.0
# 7               Villa Ballester        NaN
# 8               Villa Ballester        NaN
# 9                   Berazategui        NaN
# 10                        Tigre   110000.0
# 11                        Pilar   650000.0
# 12                        Tigre   300000.0
# 13                  Las Cañitas   600000.0
# 14                       Flores   220000.0
# 15              Villa Ballester        NaN
# 16                     Floresta    51900.0
# 17            Parque Centenario   195000.0
# 18                      Liniers   115000.0
# 19                        Tigre   195000.0
# 20                 Constitución    69000.0
# 21                 Constitución    61200.0
# 22                        Tigre  1100000.0
# 23                        Pilar   320000.0
# 24                     Recoleta   280000.0
# 25                     Recoleta   138500.0
# 26                        Tigre   190000.0
# 27                        Tigre   530000.0
# 28                Villa Udaondo   175000.0
# 29         San Antonio De Padua   120000.0
# ...                         ...        ...
# 187452                     Boca        NaN
# 187453                     Boca        NaN
# 187454                     Boca        NaN
# 187455                     Boca        NaN
# 187456                     Boca        NaN
# 187457                     Boca        NaN
# 187458                     Boca        NaN
# 187459                     Boca        NaN
# 187460                     Boca        NaN
# 187461                     Boca        NaN
# 187462                     Boca        NaN
# 187463                     Boca        NaN
# 187464                     Boca        NaN
# 187465                  Córdoba  2543236.0
# 187466         Jose Leon Suarez    80000.0
# 187467              Santa María   235000.0
# 187468                   Olivos   370000.0
# 187469               El Palomar   120000.0
# 187470          Lomas de Zamora   140000.0
# 187471                 Recoleta   142000.0
# 187472                 Recoleta   215000.0
# 187473                  Palermo   145000.0
# 187474                   Matheu   118000.0
# 187475             Barrio Norte   155000.0
# 187476            Villa Urquiza   219000.0
# 187477                  Rosario        NaN
# 187478                 Belgrano   108000.0
# 187479                 Martínez   248000.0
# 187480               Villa Luro   110000.0
# 187481  San Carlos de Bariloche        NaN
#
# [504150 rows x 2 columns]

# %%
#ordenamos por los lugares con precios mas altos 
dsRent.groupby('place_name').mean().reset_index().sort_values(by = 'price',ascending= False)[['place_name', 'price']]
# Out:
#                          place_name         price
# 247                    Cruz del Eje  1.111111e+06
# 642                        Río Tala  2.823333e+05
# 241           Country Nuevo Quilmes  1.966667e+05
# 391                        La Falda  1.966000e+05
# 845  Área de Promoción El Triángulo  1.600000e+05
# 529                   Pablo Podestá  1.433524e+05
# 72                 Barrio El Jardín  1.212120e+05
# 277                       El Retiro  1.000000e+05
# 4                   Acacias Blancas  9.355575e+04
# 447                      Los Sauces  7.000000e+04
# 640                       Río Negro  6.420000e+04
# 820                      Villa Rosa  6.291250e+04
# 334             Golf Club Argentino  6.125000e+04
# 245                  Cruce Castelar  6.000000e+04
# 169                          Cariló  5.836190e+04
# 844           coordenadas 34.255511  5.608333e+04
# 838                       Windbells  5.500000e+04
# 78                   Barrio La Isla  5.487500e+04
# 290                       Escalante  5.400000e+04
# 51            Barrio Cabos del Lago  5.366667e+04
# 268                    El Encuentro  5.350000e+04
# 58       Barrio Cerrado "La Laguna"  5.300000e+04
# 530               Pacheco Golf Club  4.881667e+04
# 558         Pilar Golf Country Club  4.800000e+04
# 17                         Altamira  4.750000e+04
# 727                Talar del lago 2  4.710714e+04
# 311                   Florida Oeste  4.705000e+04
# 704                  Santa-Catalina  4.629412e+04
# 556                   Pico Truncado  4.500000e+04
# 54     Barrio Cerrado "Buen Retiro"  4.500000e+04
# ..                              ...           ...
# 339                      Grand Bell           NaN
# 349                          Gálvez           NaN
# 359                   Huerta Grande           NaN
# 374                    Jose Ignacio           NaN
# 381              Junin de los Andes           NaN
# 444      Los Pingüinos Country Club           NaN
# 487                  Mayor Drummond           NaN
# 522                        Oliveros           NaN
# 547               Paso de la Patria           NaN
# 573                     Plaza Rocha           NaN
# 586                        Progreso           NaN
# 588                          Puelén           NaN
# 592       Puerto General San Martín           NaN
# 598             Punta Chica Village           NaN
# 617                            Reta           NaN
# 620                       Ricardone           NaN
# 628                       Rivadavia           NaN
# 634                Rosario de Lerma           NaN
# 636                         Rumenco           NaN
# 641                     Río Segundo           NaN
# 697                     Santa Lucía           NaN
# 714                        Serodino           NaN
# 721                          Susana           NaN
# 737                         Timbúes           NaN
# 743               Treinta de Agosto           NaN
# 750                        Trinidad           NaN
# 755                         Tunuyán           NaN
# 809                     Villa María           NaN
# 810                  Villa Mascardi           NaN
# 835                        Vistalba           NaN
#
# [846 rows x 2 columns]

# %%
aux = dsSell.groupby('place_name').mean().reset_index().sort_values(by = 'price',ascending= False)[['place_name', 'price']]
aux
# Out:
#                           place_name         price
# 778                          Lavalle  2.500000e+07
# 1458  Área de Promoción El Triángulo  6.000000e+06
# 393               Colonia Santa Rosa  5.000000e+06
# 1204                       San Roque  4.361614e+06
# 991                    Pico Truncado  3.800000e+06
# 473                          Dorrego  3.671752e+06
# 618                        Güer Aike  3.025000e+06
# 1446                     Yerba Buena  2.887920e+06
# 834                         Macachín  2.800000e+06
# 51              Aristóbulo del Valle  2.700000e+06
# 1282                         Tilcara  2.697500e+06
# 1263                      Tafí Viejo  2.687500e+06
# 672             Jurerê Internacional  2.561333e+06
# 1170                     San Ignacio  2.515882e+06
# 415                 Coronel Du Graty  2.500000e+06
# 347                        Cerrillos  2.483333e+06
# 907                    Monte Hermoso  2.359023e+06
# 1414               Villa San Lorenzo  2.350000e+06
# 16                           Aguaray  2.300000e+06
# 72                             Añelo  2.247333e+06
# 674                     Kilómetro 11  2.200000e+06
# 346               Centro 25 de Junio  2.190000e+06
# 1015                        Plottier  2.113808e+06
# 575                  General Cabrera  2.100000e+06
# 755                       Las Calles  2.040000e+06
# 392                     Colonia Elía  2.000000e+06
# 1339                   Villa Amancay  2.000000e+06
# 421                           Corpus  2.000000e+06
# 821                        Los Talas  1.950000e+06
# 1010                     Playa Unión  1.904935e+06
# ...                              ...           ...
# 1153                    San Clemente           NaN
# 1161                     San Esteban           NaN
# 1174              San Javier/Yacanto           NaN
# 1188                    San Martín 2           NaN
# 1200         San Patricio del Chañar           NaN
# 1215                      Santa Cruz           NaN
# 1229         Santa Rosa de Calchines           NaN
# 1235                   Santo Domingo           NaN
# 1249                   Sierras Bayas           NaN
# 1259                       Sunchales           NaN
# 1261                          Susana           NaN
# 1271                        Tartagal           NaN
# 1279                        Theobald           NaN
# 1286                          Toledo           NaN
# 1294                         Trancas           NaN
# 1296               Treinta de Agosto           NaN
# 1298                          Trenel           NaN
# 1316                       Uspallata           NaN
# 1322              Valle de Anisacate           NaN
# 1323                        Vaqueros           NaN
# 1328                            Vera           NaN
# 1335                            Vila           NaN
# 1341                   Villa Arcadia           NaN
# 1347                  Villa Belgrano           NaN
# 1383           Villa Laguna La Brava           NaN
# 1422                     Villa Unión           NaN
# 1441                        Vistalba           NaN
# 1451                   Zenón Pereyra           NaN
# 1452                  Zona Portuaria           NaN
# 1453                           Zonda           NaN
#
# [1459 rows x 2 columns]

# %%
# %matplotlib notebook

numeros = list(range(0, len(aux['place_name'])))
plt.bar(numeros, aux['price'])
plt.suptitle("Relación entre precio y lugar de propiedades en venta")
plt.xlabel("Lugar")
plt.ylabel("Precio")
plt.xticks(numeros, aux['place_name'])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
aux = dsSell.groupby('place_name').count().reset_index().sort_values(by = 'price',ascending= False)[['place_name', 'price']]
aux
# Out:
#                            place_name  price
# 857                     Mar del Plata  33685
# 451                           Córdoba  15055
# 1281                            Tigre  12115
# 929                          Nordelta  11696
# 314                   Capital Federal  11499
# 1111                          Rosario  10459
# 993                             Pilar  10249
# 250                          Belgrano   9514
# 1076                      Ramos Mejía   9379
# 1063                   Punta del Este   9019
# 954                           Palermo   8295
# 291                         Caballito   6364
# 942                            Olivos   6311
# 914                             Morón   5211
# 1171                       San Isidro   5119
# 1000                          Pinamar   4845
# 1423                    Villa Urquiza   4647
# 255                         Benavidez   4610
# 654                         Ituzaingó   4454
# 1363                     Villa Crespo   4398
# 198                      Barrio Norte   4332
# 1083                         Recoleta   4257
# 555                            Flores   4241
# 867                          Martínez   4208
# 620                             Haedo   4072
# 726                          La Plata   3942
# 1332                    Vicente López   3845
# 32                            Almagro   3710
# 1162                     San Fernando   3685
# 1192                       San Miguel   3518
# ...                               ...    ...
# 1030                  Primero de Mayo      0
# 1028                  Presidente Roca      0
# 59                       Arroyo Leyes      0
# 231               Barrio San Salvador      0
# 816                         Los Pozos      0
# 56                           Arroyito      0
# 825                    Lucas González      0
# 999                        Pilcaniyeu      0
# 54                            Arocena      0
# 1347                   Villa Belgrano      0
# 66                            Ataliva      0
# 401                        Concepción      0
# 1328                             Vera      0
# 1316                        Uspallata      0
# 1077                Ramón Santamarina      0
# 638                    Hoyo de Epuyén      0
# 780                           Lehmann      0
# 1322               Valle de Anisacate      0
# 1323                         Vaqueros      0
# 1069                             Raco      0
# 79                          Balnearia      0
# 631                          Helvecia      0
# 789       Lobos: cabecera del partido      0
# 1335                             Vila      0
# 74                     Bahía San Blas      0
# 1053                     Puerto Yeruá      0
# 1051                 Puerto Pirámides      0
# 133   Barrio Cerrado "Las Margaritas"      0
# 1341                    Villa Arcadia      0
# 339                   Cañada de Gómez      0
#
# [1459 rows x 2 columns]

# %%
# %matplotlib notebook

numeros = list(range(0, len(aux['place_name'])))
plt.bar(numeros, aux['price'])
plt.suptitle("Relación entre lugar y cantidad de publicaciones de ese lugar")
plt.xlabel("Lugar")
plt.ylabel("Precio")
plt.xticks(numeros, aux['place_name'])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
for i in range(0, len(dsRent.columns)):
    for j in range(i+1, len(dsRent.columns)):
        a = dsRent[dsRent.columns[i]]
        b = dsRent[dsRent.columns[j]]

# %%
#formatear datos stirng a float
#convertimos el formato de la fecha
dsRent['created_on'] = dsRent['created_on'] .map(lambda x: x.split('-')[0]+x.split('-')[1]+x.split('-')[2])
dsRent
# Out:
#       created_on currency                                        description  \
# 0       20120919      ARS                                                NaN
# 1       20120927      ARS                                                NaN
# 2       20121010      ARS                                                NaN
# 3       20121010      ARS                                                NaN
# 4       20121010      ARS                                                NaN
# 5       20121010      USD                                                NaN
# 6       20121010      USD                                                NaN
# 7       20121010      ARS                                                NaN
# 8       20121010      USD                                                NaN
# 9       20121010      ARS                                                NaN
# 10      20121010      USD                                                NaN
# 11      20121010      USD                                                NaN
# 12      20121010      USD                                                NaN
# 13      20121010      USD                                                NaN
# 14      20121010      ARS                                                NaN
# 15      20121010      ARS                                                NaN
# 16      20121010      ARS                                                NaN
# 17      20121010      ARS                                                NaN
# 18      20121010      ARS                                                NaN
# 19      20121010      USD                                                NaN
# 20      20121012      ARS                                                NaN
# 21      20121013      ARS                                                NaN
# 22      20121018      ARS                                                NaN
# 23      20121021      USD                                                NaN
# 24      20121022      USD                                                NaN
# 25      20121022      ARS                                                NaN
# 26      20121022      ARS                                                NaN
# 27      20121022      USD                                                NaN
# 28      20121022      USD                                                NaN
# 29      20121022      USD                                                NaN
# ...          ...      ...                                                ...
# 26312   20170801      ARS  LUMINOSO SEMIPISO 2 AMB. IMPECABLE & AMPLIO. L...
# 26313   20170801      ARS  Casa en 2 plantas de 3 dormitorios. Living com...
# 26314   20170801      USD  Ubicación exclusiva, de Libertador al río, con...
# 26315   20170801      ARS  Living comedor 4.00 x 3.00, con piso de parque...
# 26316   20170801      NaN  Local a estrenar de 4,10 de frente por 11 de f...
# 26317   20170801      ARS   ALQUILER DEPARTAMENTO AMBIENTE DIVISIBLE A ES...
# 26318   20170801      ARS  Amplio departamento de 3 ambientes. Cuenta con...
# 26319   20170801      ARS  Hermoso 2 ambientes  amplios en Alquiler  53m2...
# 26320   20170801      ARS  ALQUILER DEPARTAMENTO ESPECTACULAR- AMOBLADO C...
# 26321   20170801      USD  ALQUILER DEPARTAMENTO ESPECTACULAR- AMOBLADO C...
# 26322   20170801      ARS  Departamento de 3 ambientes en primer piso por...
# 26323   20170801      ARS  Excelente depto. 2 amb. en Recoleta. excelente...
# 26324   20170801      NaN  Hermoso chalet  en Country Club Venado I, la p...
# 26325   20170801      ARS  Dos Locales, se pueden alquilar en forma indiv...
# 26326   20170801      ARS  Muy buen depósito sobre importante Avenida a 1...
# 26327   20170801      ARS  * Departamento de 2 ambientes.* 1 Ascensor pri...
# 26328   20170801      ARS  Departamento en Alquiler, estilo duplex. Tres ...
# 26329   20170801      NaN  Posesion Agosto2017Alquiler $3200 + 30%CARACTE...
# 26330   20170801      ARS  Alquiler por dos años .  Casa en Complejo Vill...
# 26331   20170801      ARS  Duplex de 2 cuartos, baño principal, toilete ,...
# 26332   20170801      ARS  Imperdible  en Torre Quartier!!!,   3 ambiente...
# 26333   20170801      ARS  Ph en Planta baja de tres ambientes. Living co...
# 26334   20170801      ARS  Te invitamos a conocer:Departamento de un dorm...
# 26335   20170801      ARS  Monoambiente a estrenar en Chilavert, sobre ca...
# 26336   20170801      ARS  Departamento de 1 dormitorio , cocina comedor ...
# 26337   20170801      NaN  Posesion Sept2017 Alquiler VALOR PENDIENTE DE ...
# 26338   20170801      ARS  Departamento antiguo hecho a nuevo manteniendo...
# 26339   20170801      ARS  HERMOSO CHALET EN UNA PLANTA, CUENTA CON AMPLI...
# 26340   20170801      ARS  Chalet en 2 plantas  , 3 dormitorios , 2 baños...
# 26341   20170801      ARS   DUPLEX MUY LUMINOSO, ABERTURAS DE ALUMINIO, P...
#
#                    expenses extra  floor  geonames_id  \
# 0                       NaN   NaN    NaN          NaN
# 1                      2500   NaN    9.0    3430234.0
# 2                       NaN   NaN   14.0    3429760.0
# 3                       NaN   NaN    NaN          NaN
# 4                       NaN   NaN    NaN          NaN
# 5                       NaN   NaN    NaN          NaN
# 6                       NaN   NaN    NaN          NaN
# 7                      3000   NaN    7.0    3430234.0
# 8                       NaN   NaN    1.0          NaN
# 9                       NaN   NaN   19.0    3430234.0
# 10                      NaN   NaN    5.0    3430234.0
# 11                      NaN   NaN   25.0          NaN
# 12                     5200   NaN   27.0    3430234.0
# 13                      NaN   NaN   19.0    3430234.0
# 14                      NaN   NaN    4.0          NaN
# 15     $ 1475 c/cable y agu   NaN   11.0    3429595.0
# 16                      NaN   NaN    1.0    3427387.0
# 17                    $1500   NaN    3.0    3430234.0
# 18                    $3500   NaN    9.0    3429595.0
# 19                      NaN   NaN   11.0    3430234.0
# 20                      NaN   NaN    NaN          NaN
# 21                      NaN   NaN    NaN    3436152.0
# 22                     1000   NaN    NaN          NaN
# 23                      NaN   NaN    NaN          NaN
# 24                      NaN   NaN    NaN          NaN
# 25                      NaN   NaN    NaN          NaN
# 26                      NaN   NaN    NaN          NaN
# 27                      NaN   NaN    NaN          NaN
# 28                      NaN   NaN    NaN          NaN
# 29                      NaN   NaN    NaN          NaN
# ...                     ...   ...    ...          ...
# 26312                  1200   NaN    NaN    3433910.0
# 26313                   NaN   NaN    NaN          NaN
# 26314                   NaN   NaN    NaN    3436508.0
# 26315                  4500   NaN    NaN    3430234.0
# 26316                   NaN   NaN    NaN    3430291.0
# 26317                  1500   NaN    NaN    3433775.0
# 26318                  1222   NaN    NaN    3430570.0
# 26319                  1440   NaN    NaN    3435259.0
# 26320                   NaN   NaN    NaN    3436077.0
# 26321                   NaN   NaN    NaN    3436077.0
# 26322                  1500   NaN    NaN          NaN
# 26323                  1900   NaN    NaN    3429595.0
# 26324                 12000   NaN    NaN    3434003.0
# 26325                  1300   NaN    NaN    3860259.0
# 26326                   NaN   NaN    NaN          NaN
# 26327                  2500   NaN    NaN    3435874.0
# 26328                  6500   NaN    NaN    3430234.0
# 26329                   200   NaN    NaN    3838574.0
# 26330                  5400   NaN    NaN    3427753.0
# 26331                   NaN   NaN    NaN    3435907.0
# 26332                  6700   NaN    NaN    3430234.0
# 26333                   NaN   NaN    NaN    3427467.0
# 26334                   NaN   NaN    NaN    3860259.0
# 26335                   NaN   NaN    NaN    3427467.0
# 26336                   800   NaN    NaN    3435907.0
# 26337                   NaN   NaN    NaN    3838574.0
# 26338                  3600   NaN    NaN    3433955.0
# 26339                   NaN   NaN    NaN    3430992.0
# 26340                   NaN   NaN    NaN    3430813.0
# 26341                  1000   NaN    NaN    3434130.0
#
#                                              id  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# 5                                           NaN
# 6                                           NaN
# 7                                           NaN
# 8                                           NaN
# 9                                           NaN
# 10                                          NaN
# 11                                          NaN
# 12                                          NaN
# 13                                          NaN
# 14                                          NaN
# 15                                          NaN
# 16                                          NaN
# 17                                          NaN
# 18                                          NaN
# 19                                          NaN
# 20                                          NaN
# 21                                          NaN
# 22                                          NaN
# 23                                          NaN
# 24                                          NaN
# 25                                          NaN
# 26                                          NaN
# 27                                          NaN
# 28                                          NaN
# 29                                          NaN
# ...                                         ...
# 26312  454c5c71e0cbcc2101b9d6e355eb21ccf4663f80
# 26313  3da2d0299cd7b87d17d4c91cab4d4e7d83eea951
# 26314  6df7525ba52cbb92be2461a6c28bce7f5c99de78
# 26315  cb6fa4aa6dd71a6c93afa67026d451a4a210e5c8
# 26316  3093ba9f681f7255c5d1771eae5cc9e547c3ec9c
# 26317  7450e4c820e865131930d56ae15c3e12db99c52a
# 26318  3484c9ee8623d4d591d13f39957b51ba74ef6a8e
# 26319  9a1af144af6455ba5150a05ba8e01bedaabb6a99
# 26320  835a5444ddae66f4b26a477e7c48f55920f88eba
# 26321  e9051b2852adf1d7056a76c3ef07486273345339
# 26322  c1f3e4a6da9d51f76a2a370d45bb251b81a8ac54
# 26323  abb3f4457eab66ba03c8a1fead154078776e32bb
# 26324  9d59e05767e5cbfb56739c658f520f61234abaa1
# 26325  b43931ecb95c987811c902e46ec8bc408f348d95
# 26326  803ddc25a5b9bd594b55263df730a2dfb9f4e0d7
# 26327  a7fc6a3453f7784258bad1e4d0014171100e6370
# 26328  7c1e483439ff425215f0879e01f1c83be41761ec
# 26329  743010cd360807d2fe900279e9db72d1b9f8002f
# 26330  4b8606b70de3e49d7690f7781d36c31fd40200d2
# 26331  b31b1d09b785075e61ab8b05eba10be64215e2c2
# 26332  b413f9b277582b9b0be0a9004bb77a5e97bb97e1
# 26333  553b0486b2ae26398d1a2ed550977eb8e402a696
# 26334  222919d45b3bf41eee4022e46d695496386e760e
# 26335  72946bad61ed3c3c4fa89fd10679a26d4e0ae0e8
# 26336  fa8cd94a5a014217dcbc57f47c0fe16b757e04df
# 26337  2fa55dead202bd108ea8f9e10c182b25f4f049d7
# 26338  ec2751bd1e2c799a63c18e4a4ae4ec03bdc32a0a
# 26339  941812a09102edd24de61a0fa9fefbb62a132c09
# 26340  315e3ee6f8ba63a44867ae973d53738ba35b1ed6
# 26341  85ea66a24b0f52dfb70e24348989c3c8e10f75ed
#
#                                          image_thumbnail        lat  \
# 0      http://cf-thumbs.properati.com.ar/diH5XHckfc0t...        NaN
# 1      http://cf-thumbs.properati.com.ar/esk2qFDd1keI... -34.576888
# 2      http://cf-thumbs.properati.com.ar/ZGH-kBypKFhg... -34.609439
# 3      http://cf-thumbs.properati.com.ar/RNF8bdTcX1fG...        NaN
# 4      http://cf-thumbs.properati.com.ar/VkCbplU9RvP9... -34.579306
# 5      http://cf-thumbs.properati.com.ar/sQeslmJgpK88... -34.452498
# 6      http://cf-thumbs.properati.com.ar/ViwyYG4HzXtA... -34.452498
# 7      http://cf-thumbs.properati.com.ar/eTm-_kx_MkEB... -34.585293
# 8      http://cf-thumbs.properati.com.ar/jqIlP3r3OS6j... -34.565110
# 9      http://cf-thumbs.properati.com.ar/DkbXvQHoL5FM... -34.565110
# 10     http://cf-thumbs.properati.com.ar/-bTcwJafqYth... -34.576888
# 11     http://cf-thumbs.properati.com.ar/iTW-tqmOmSmH... -34.582473
# 12     http://cf-thumbs.properati.com.ar/DIrjT6dxfJpp... -34.575551
# 13     http://cf-thumbs.properati.com.ar/BvdkbOZdFKSM... -34.587595
# 14     http://cf-thumbs.properati.com.ar/5h3ItzzEY-ao... -34.577764
# 15     http://cf-thumbs.properati.com.ar/YZirPhinIcIb... -34.592715
# 16     http://cf-thumbs.properati.com.ar/VhTeo29CW8t6... -34.581781
# 17     http://cf-thumbs.properati.com.ar/wRl6IcSRomMD... -34.577764
# 18     http://cf-thumbs.properati.com.ar/xfmsirCqp-kO... -34.594460
# 19     http://cf-thumbs.properati.com.ar/abnw2TR5TF3x... -34.577593
# 20     http://cf-thumbs.properati.com.ar/baNJ3RTx95_x...        NaN
# 21     http://cf-thumbs.properati.com.ar/MSA7QtNmPBHx... -34.753725
# 22     http://cf-thumbs.properati.com.ar/OcWF2DEX6Bc-...        NaN
# 23     http://cf-thumbs.properati.com.ar/Zsu33Km1Gb33... -34.452498
# 24     http://cf-thumbs.properati.com.ar/xQpq3ychfUmi...        NaN
# 25     http://cf-thumbs.properati.com.ar/dOu5gCxLBNPV... -34.452498
# 26     http://cf-thumbs.properati.com.ar/VTwjzYZmlbQL... -34.452498
# 27     http://cf-thumbs.properati.com.ar/7J8-H2u9n62-... -34.452498
# 28     http://cf-thumbs.properati.com.ar/ErVTm8s-fXxV... -34.452498
# 29     http://cf-thumbs.properati.com.ar/6a7Q-tzNhbUx... -34.452498
# ...                                                  ...        ...
# 26312  https://thumbs4.properati.com/6/pz7RMLPaMg9nAU... -34.628840
# 26313                                                NaN        NaN
# 26314  https://thumbs4.properati.com/9/6ANi_fGu1zE7Ju...        NaN
# 26315  https://thumbs4.properati.com/4/WAFYh0MN2YJRs6...        NaN
# 26316  https://thumbs4.properati.com/6/0lvOucUK7iUY_0... -34.602142
# 26317  https://thumbs4.properati.com/7/EC6eXGIJ59mcYr... -34.570639
# 26318  https://thumbs4.properati.com/5/QkI9KEK6f-sdfJ... -34.614701
# 26319  https://thumbs4.properati.com/4/Zbuiz5jp9l68fN... -34.607909
# 26320  https://thumbs4.properati.com/3/kFumBpkVy8KlpN... -34.570657
# 26321  https://thumbs4.properati.com/3/kFumBpkVy8KlpN... -34.570657
# 26322  https://thumbs4.properati.com/3/5aubLrym5h8XLo... -34.763187
# 26323  https://thumbs4.properati.com/7/w7jzph8ym9-Swt...        NaN
# 26324  https://thumbs4.properati.com/6/rSLYlHoTZJo0JI...        NaN
# 26325  https://thumbs4.properati.com/4/HW3jvK8G5JNuUP...        NaN
# 26326  https://thumbs4.properati.com/4/8A4NpAvpVKNMSo...        NaN
# 26327  https://thumbs4.properati.com/4/i6_WWzzgxGWa2J... -34.634321
# 26328  https://thumbs4.properati.com/0/keNijVv9oxdcN9... -34.587422
# 26329  https://thumbs4.properati.com/1/GW_kRdHYPcfaTj...        NaN
# 26330  https://thumbs4.properati.com/8/q8-mPBVv3vmtdL...        NaN
# 26331  https://thumbs4.properati.com/2/xUdmShPmrlqpaH...        NaN
# 26332  https://thumbs4.properati.com/4/dltErDTVvwcxyM... -34.576889
# 26333  https://thumbs4.properati.com/5/b8EocHJVqqW6Rl... -34.544354
# 26334  https://thumbs4.properati.com/4/x5VjbmJtuUwohI...        NaN
# 26335  https://thumbs4.properati.com/8/rL-yM8jT3RCSR8... -34.544354
# 26336  https://thumbs4.properati.com/5/tfxKO_5-uHWiXD...        NaN
# 26337  https://thumbs4.properati.com/0/IxzgtJ6Lp7SF26...        NaN
# 26338  https://thumbs4.properati.com/3/UGhHNUyUnAxZei...        NaN
# 26339  https://thumbs4.properati.com/0/GBJBFA2YQpwSDV...        NaN
# 26340  https://thumbs4.properati.com/7/6MW_YYRMsZU9xO...        NaN
# 26341  https://thumbs4.properati.com/6/PPHOGr2zMm5_vY...        NaN
#
#                              ...                         price_per_m2  \
# 0                            ...                                  NaN
# 1                            ...                                  NaN
# 2                            ...                                  NaN
# 3                            ...                                  NaN
# 4                            ...                                  NaN
# 5                            ...                                  NaN
# 6                            ...                                  NaN
# 7                            ...                                  NaN
# 8                            ...                                  NaN
# 9                            ...                                  NaN
# 10                           ...                                  NaN
# 11                           ...                                  NaN
# 12                           ...                                  NaN
# 13                           ...                                  NaN
# 14                           ...                                  NaN
# 15                           ...                                  NaN
# 16                           ...                                  NaN
# 17                           ...                                  NaN
# 18                           ...                                  NaN
# 19                           ...                                  NaN
# 20                           ...                                  NaN
# 21                           ...                                  NaN
# 22                           ...                                  NaN
# 23                           ...                                  NaN
# 24                           ...                                  NaN
# 25                           ...                                  NaN
# 26                           ...                                  NaN
# 27                           ...                                  NaN
# 28                           ...                                  NaN
# 29                           ...                                  NaN
# ...                          ...                                  ...
# 26312                        ...                           209.375000
# 26313                        ...                            76.470588
# 26314                        ...                            11.165049
# 26315                        ...                           318.965517
# 26316                        ...                                  NaN
# 26317                        ...                           229.729730
# 26318                        ...                           159.090909
# 26319                        ...                           153.333333
# 26320                        ...                                  NaN
# 26321                        ...                                  NaN
# 26322                        ...                                  NaN
# 26323                        ...                           194.444444
# 26324                        ...                                  NaN
# 26325                        ...                                  NaN
# 26326                        ...                            93.750000
# 26327                        ...                           200.000000
# 26328                        ...                           300.000000
# 26329                        ...                                  NaN
# 26330                        ...                           155.555556
# 26331                        ...                                  NaN
# 26332                        ...                           357.142857
# 26333                        ...                           123.076923
# 26334                        ...                                  NaN
# 26335                        ...                           160.000000
# 26336                        ...                                  NaN
# 26337                        ...                                  NaN
# 26338                        ...                           110.000000
# 26339                        ...                            85.714286
# 26340                        ...                           196.078431
# 26341                        ...                            81.000000
#
#        price_usd_per_m2                                      properati_url  \
# 0             15.460913  http://www.properati.com.ar/u86_alquiler_casa_...
# 1             21.166750  http://www.properati.com.ar/w7u_alquiler_depar...
# 2             21.166750  http://www.properati.com.ar/13kc_alquiler_depa...
# 3             10.643829  http://www.properati.com.ar/148s_alquiler_casa...
# 4             13.025692  http://www.properati.com.ar/14cc_alquiler_casa...
# 5              9.183673  http://www.properati.com.ar/14fk_alquiler_casa...
# 6              8.000000  http://www.properati.com.ar/14fl_alquiler_casa...
# 7             14.211929  http://www.properati.com.ar/1690_alquiler_depa...
# 8             27.500000  http://www.properati.com.ar/1771_alquiler_depa...
# 9             33.866789  http://www.properati.com.ar/177b_alquiler_depa...
# 10            20.833333  http://www.properati.com.ar/177e_alquiler_depa...
# 11            27.058824  http://www.properati.com.ar/177g_alquiler_depa...
# 12            21.666667  http://www.properati.com.ar/177i_alquiler_depa...
# 13            25.096525  http://www.properati.com.ar/177k_alquiler_depa...
# 14            17.265412  http://www.properati.com.ar/177p_alquiler_depa...
# 15            15.522167  http://www.properati.com.ar/17gm_alquiler_depa...
# 16            13.025641  http://www.properati.com.ar/17gt_alquiler_depa...
# 17            24.612442  http://www.properati.com.ar/1d0z_alquiler_depa...
# 18            16.282115  http://www.properati.com.ar/1d6a_alquiler_depa...
# 19            18.987342  http://www.properati.com.ar/1d6b_alquiler_depa...
# 20            11.176000  http://www.properati.com.ar/1fhq_alquiler_depa...
# 21             7.902244  http://www.properati.com.ar/1fqr_venta_casa_ba...
# 22            17.265294  http://www.properati.com.ar/1fsi_alquiler_depa...
# 23                  NaN  http://www.properati.com.ar/1nw3_alquiler_casa...
# 24            14.000000  http://www.properati.com.ar/1v90_alquiler_casa...
# 25            20.118812  http://www.properati.com.ar/1v96_alquiler_casa...
# 26            11.288889  http://www.properati.com.ar/1vhf_alquiler_casa...
# 27             8.888889  http://www.properati.com.ar/1vhg_alquiler_casa...
# 28             8.333333  http://www.properati.com.ar/1vhh_alquiler_casa...
# 29            11.333333  http://www.properati.com.ar/1vhi_alquiler_casa...
# ...                 ...                                                ...
# 26312               NaN  http://www.properati.com.ar/1cjak_alquiler_dep...
# 26313               NaN  http://www.properati.com.ar/1cjb1_alquiler_cas...
# 26314          7.044410  http://www.properati.com.ar/1cjb7_alquiler_cas...
# 26315         17.008852  http://www.properati.com.ar/1cjbc_alquiler_dep...
# 26316               NaN  http://www.properati.com.ar/1cjbe_alquiler_loc...
# 26317         11.086279  http://www.properati.com.ar/1cjbj_alquiler_dep...
# 26318          8.011837  http://www.properati.com.ar/1cjbu_alquiler_dep...
# 26319          7.301321  http://www.properati.com.ar/1cjch_alquiler_dep...
# 26320         18.928187  http://www.properati.com.ar/1cjcm_alquiler_dep...
# 26321         18.750000  http://www.properati.com.ar/1cjcn_alquiler_dep...
# 26322               NaN  http://www.properati.com.ar/1cjd4_alquiler_dep...
# 26323         10.905000  http://www.properati.com.ar/1cjdc_alquiler_dep...
# 26324               NaN  http://www.properati.com.ar/1cjdg_alquiler_cas...
# 26325          6.169200  http://www.properati.com.ar/1cjdj_alquiler_loc...
# 26326          4.103675  http://www.properati.com.ar/1cjds_alquiler_loc...
# 26327         10.196818  http://www.properati.com.ar/1cjdx_alquiler_dep...
# 26328         10.077500  http://www.properati.com.ar/1cjeb_alquiler_cas...
# 26329               NaN  http://www.properati.com.ar/1cjee_alquiler_dep...
# 26330          6.625907  http://www.properati.com.ar/1cjef_alquiler_cas...
# 26331               NaN  http://www.properati.com.ar/1cjeg_alquiler_cas...
# 26332         20.029796  http://www.properati.com.ar/1cjek_alquiler_dep...
# 26333               NaN  http://www.properati.com.ar/1cjfo_alquiler_ph_...
# 26334               NaN  http://www.properati.com.ar/1cjfq_alquiler_dep...
# 26335               NaN  http://www.properati.com.ar/1cjfs_alquiler_dep...
# 26336               NaN  http://www.properati.com.ar/1cjfz_alquiler_dep...
# 26337               NaN  http://www.properati.com.ar/1cjg3_alquiler_dep...
# 26338          6.169111  http://www.properati.com.ar/1cjgg_alquiler_dep...
# 26339               NaN  http://www.properati.com.ar/1cjgh_alquiler_cas...
# 26340         10.996797  http://www.properati.com.ar/1cjgj_alquiler_cas...
# 26341          4.542700  http://www.properati.com.ar/1cjgk_alquiler_cas...
#
#       property_type rooms                state_name  surface_covered_in_m2  \
# 0             house   NaN                       NaN                    NaN
# 1         apartment   4.0                       NaN                    NaN
# 2         apartment   4.0                       NaN                    NaN
# 3             house   NaN                       NaN                    NaN
# 4             house   4.0                       NaN                    NaN
# 5             house   3.0                       NaN                    NaN
# 6             house   4.0                       NaN                    NaN
# 7         apartment   5.0                       NaN                    NaN
# 8         apartment   4.0                       NaN                    NaN
# 9         apartment   4.0                       NaN                    NaN
# 10        apartment   3.0                       NaN                    NaN
# 11        apartment   3.0                       NaN                    NaN
# 12        apartment   5.0                       NaN                    NaN
# 13        apartment   5.0                       NaN                    NaN
# 14        apartment   4.0                       NaN                    NaN
# 15        apartment   2.0                       NaN                    NaN
# 16        apartment   3.0                       NaN                    NaN
# 17        apartment   3.0                       NaN                    NaN
# 18        apartment   4.0                       NaN                    NaN
# 19        apartment   3.0                       NaN                    NaN
# 20        apartment   1.0                       NaN                    NaN
# 21            house   NaN                       NaN                    NaN
# 22        apartment   1.0                       NaN                    NaN
# 23            house   2.0                       NaN                    NaN
# 24            house   NaN                       NaN                    NaN
# 25            house   2.0                       NaN                    NaN
# 26            house   2.0                       NaN                    NaN
# 27            house   NaN                       NaN                    NaN
# 28            house   2.0                       NaN                    NaN
# 29            house   NaN                       NaN                    NaN
# ...             ...   ...                       ...                    ...
# 26312     apartment   NaN           Capital Federal                   32.0
# 26313         house   NaN    Bs.As. G.B.A. Zona Sur                   85.0
# 26314         house   NaN  Bs.As. G.B.A. Zona Norte                  412.0
# 26315     apartment   NaN           Capital Federal                   58.0
# 26316         store   NaN           Capital Federal                   50.0
# 26317     apartment   NaN           Capital Federal                   37.0
# 26318     apartment   NaN           Capital Federal                   44.0
# 26319     apartment   NaN           Capital Federal                   45.0
# 26320     apartment   NaN           Capital Federal                    NaN
# 26321     apartment   NaN           Capital Federal                    NaN
# 26322     apartment   NaN    Bs.As. G.B.A. Zona Sur                    NaN
# 26323     apartment   NaN           Capital Federal                   36.0
# 26324         house   NaN    Bs.As. G.B.A. Zona Sur                  140.0
# 26325         store   NaN                   Córdoba                    NaN
# 26326         store   NaN  Bs.As. G.B.A. Zona Norte                  480.0
# 26327     apartment   NaN           Capital Federal                   40.0
# 26328         house   NaN           Capital Federal                  115.0
# 26329     apartment   NaN                  Santa Fe                    NaN
# 26330         house   NaN  Bs.As. G.B.A. Zona Norte                  180.0
# 26331         house   NaN  Bs.As. G.B.A. Zona Norte                    NaN
# 26332     apartment   NaN           Capital Federal                   98.0
# 26333            PH   NaN  Bs.As. G.B.A. Zona Norte                   65.0
# 26334     apartment   NaN                   Córdoba                    NaN
# 26335     apartment   NaN  Bs.As. G.B.A. Zona Norte                   25.0
# 26336     apartment   NaN  Bs.As. G.B.A. Zona Norte                    NaN
# 26337     apartment   NaN                  Santa Fe                   90.0
# 26338     apartment   NaN           Capital Federal                   90.0
# 26339         house   NaN    Bs.As. G.B.A. Zona Sur                  140.0
# 26340         house   NaN  Bs.As. G.B.A. Zona Norte                  153.0
# 26341         house   NaN  Bs.As. G.B.A. Zona Norte                  100.0
#
#        surface_in_m2  surface_total_in_m2  \
# 0              230.0                  NaN
# 1              120.0                  NaN
# 2              200.0                  NaN
# 3              350.0                  NaN
# 4              195.0                  NaN
# 5              490.0                  NaN
# 6              500.0                  NaN
# 7              280.0                  NaN
# 8              200.0                  NaN
# 9              190.0                  NaN
# 10             120.0                  NaN
# 11              85.0                  NaN
# 12             300.0                  NaN
# 13             259.0                  NaN
# 14             255.0                  NaN
# 15              60.0                  NaN
# 16              78.0                  NaN
# 17              86.0                  NaN
# 18             156.0                  NaN
# 19              79.0                  NaN
# 20              50.0                  NaN
# 21             450.0                  NaN
# 22              51.0                  NaN
# 23               NaN                  NaN
# 24             450.0                  NaN
# 25             101.0                  NaN
# 26             180.0                  NaN
# 27             450.0                  NaN
# 28             300.0                  NaN
# 29             150.0                  NaN
# ...              ...                  ...
# 26312            NaN                  NaN
# 26313            NaN                  NaN
# 26314            NaN                653.0
# 26315            NaN                 61.0
# 26316            NaN                  NaN
# 26317            NaN                 43.0
# 26318            NaN                 49.0
# 26319            NaN                 53.0
# 26320            NaN                160.0
# 26321            NaN                160.0
# 26322            NaN                  NaN
# 26323            NaN                 36.0
# 26324            NaN                  NaN
# 26325            NaN                 50.0
# 26326            NaN                615.0
# 26327            NaN                 44.0
# 26328            NaN                192.0
# 26329            NaN                  NaN
# 26330            NaN                237.0
# 26331            NaN                  NaN
# 26332            NaN                 98.0
# 26333            NaN                  NaN
# 26334            NaN                  NaN
# 26335            NaN                  NaN
# 26336            NaN                  NaN
# 26337            NaN                108.0
# 26338            NaN                 90.0
# 26339            NaN                  NaN
# 26340            NaN                153.0
# 26341            NaN                100.0
#
#                                                    title
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# 5                                                    NaN
# 6                                                    NaN
# 7                                                    NaN
# 8                                                    NaN
# 9                                                    NaN
# 10                                                   NaN
# 11                                                   NaN
# 12                                                   NaN
# 13                                                   NaN
# 14                                                   NaN
# 15                                                   NaN
# 16                                                   NaN
# 17                                                   NaN
# 18                                                   NaN
# 19                                                   NaN
# 20                                                   NaN
# 21                                                   NaN
# 22                                                   NaN
# 23                                                   NaN
# 24                                                   NaN
# 25                                                   NaN
# 26                                                   NaN
# 27                                                   NaN
# 28                                                   NaN
# 29                                                   NaN
# ...                                                  ...
# 26312                            Departamento - Floresta
# 26313                                     Entre Rios 620
# 26314  Casa en alquiler, 4 dormitorios, jardín con pa...
# 26315                         3 ambientes Palermo  Nuevo
# 26316                                   Aguero y Lavalle
# 26317  ALQUILER DEPARTAMENTO AMBIENTE DIVISIBLE A EST...
# 26318                Amplio departamento de 3 ambientes.
# 26319                            Departamento - Congreso
# 26320  ALQUILER DEPARTAMENTO ESPECTACULAR- AMOBLADO C...
# 26321  ALQUILER DEPARTAMENTO ESPECTACULAR- AMOBLADO C...
# 26322               Departamento - Lomas de Zamora Oeste
# 26323  Departamento - Recoleta 2 AMB. MUY LUMINOSO PI...
# 26324            Oportunidad!!! No dudes en consultarnos
# 26325  Local en Edificio Saint Michelle. San Jerónimo...
# 26326  Muy buen depósito sobre importante Avenida a 1...
# 26327            Departamento de 2 ambientes - Caballito
# 26328                                     Casa - Palermo
# 26329                               Departamento - Oeste
# 26330                              Casa - Santa Catalina
# 26331                            Casa - Centro (Campana)
# 26332                             Departamento - Palermo
# 26333                 PH en PB - 3 ambientes - Chilavert
# 26334                        Departamento en General Paz
# 26335                Monoambiente a estrenar - Chilavert
# 26336                    Departamento - Centro (Campana)
# 26337                        Departamento - Centro Norte
# 26338          impecable 3 amb frente a Plaza San Martín
# 26339                                Casa - Luis Guillon
# 26340                                    Casa - Martinez
# 26341                                 Duplex en alquiler
#
# [111628 rows x 28 columns]

# %%
#pasar precios a pesos argentinos


#usamos un promedio aprox del dolar en estos 4 años. se peude hacer ocn mas precisión
dsRent['preciosEnArs'] = dsRent[['price', 'currency']].apply(lambda x: x[0] if x[1] == 'ARS' else x[0] * 14, axis=1) 

dsRent['preciosEnArs']
# Out:
# 0        21000.0
# 1        15000.0
# 2        25000.0
# 3        22000.0
# 4        15000.0
# 5        63000.0
# 6        56000.0
# 7        23500.0
# 8        77000.0
# 9        38000.0
# 10       35000.0
# 11       32200.0
# 12       91000.0
# 13       91000.0
# 14       26000.0
# 15        5500.0
# 16        6000.0
# 17       12500.0
# 18       15000.0
# 19       21000.0
# 20        3300.0
# 21       21000.0
# 22        5200.0
# 23       70000.0
# 24       88200.0
# 25       12000.0
# 26       12000.0
# 27       56000.0
# 28       35000.0
# 29       23800.0
#           ...
# 26312     6700.0
# 26313     6500.0
# 26314    64400.0
# 26315    18500.0
# 26316        NaN
# 26317     8500.0
# 26318     7000.0
# 26319     6900.0
# 26320    54000.0
# 26321    42000.0
# 26322     8300.0
# 26323     7000.0
# 26324        NaN
# 26325     5500.0
# 26326    45000.0
# 26327     8000.0
# 26328    34500.0
# 26329        NaN
# 26330    28000.0
# 26331    10000.0
# 26332    35000.0
# 26333     8000.0
# 26334    11400.0
# 26335     4000.0
# 26336     6500.0
# 26337        NaN
# 26338     9900.0
# 26339    12000.0
# 26340    30000.0
# 26341     8100.0
# Name: preciosEnArs, dtype: float64

# %%
#vemos como evolucionan algunos features en el tiempo para la renta

cantidadRentEnAnios = dsRent.groupby('created_on').count().reset_index().rename(columns={'price':'cantidad'}).sort_values(by = 'created_on',ascending= True)[['created_on', 'cantidad']]
preciosRentEnAnios = dsRent.groupby('created_on').mean().reset_index().sort_values(by = 'created_on',ascending= True)[['created_on', 'preciosEnArs']]

# %%
# %matplotlib notebook

numeros = list(range(0, len(cantidadRentEnAnios['created_on'])))
plt.bar(numeros, cantidadRentEnAnios['cantidad'])
plt.suptitle("Evolución de cantidad de rentas en el tiempo")
plt.xlabel("Tiempo")
plt.ylabel("Cantidad Rentas")
plt.xticks(numeros, cantidadRentEnAnios['created_on'])
plt.show()

#ajustar ESCALAS
# Out:
# <img src="data:image/png;base64,..." width="896">

# %%
# %matplotlib notebook

numeros = list(range(0, len(preciosRentEnAnios['created_on'])))
plt.bar(numeros, preciosRentEnAnios['preciosEnArs'])
plt.suptitle("Evolución del precio a lo largo del tiempo")
plt.xlabel("Tiempo")
plt.ylabel("Precio")
plt.xticks(numeros, preciosRentEnAnios['created_on'])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
dsRent['currency'].value_counts()
# Out:
# ARS    54899
# USD    45351
# Name: currency, dtype: int64

# %%
#Cantidad de viviendas vendidas en dolares y pesos a lo largo del tiempo
cantidadRentEnAniosEnDolares = dsRent[dsRent['currency'] == 'USD'].groupby('created_on').count().reset_index().rename(columns={'price':'cantidad'}).sort_values(by = 'created_on',ascending= True)[['created_on', 'cantidad']]
cantidadRentEnAniosEnPesos = dsRent[dsRent['currency'] == 'ARS'].groupby('created_on').count().reset_index().rename(columns={'price':'cantidad'}).sort_values(by = 'created_on',ascending= True)[['created_on', 'cantidad']]

# %%
# %matplotlib notebook

numeros = list(range(0, len(cantidadRentEnAniosEnDolares['created_on'])))
plt.bar(numeros, cantidadRentEnAniosEnDolares['cantidad'])
plt.suptitle("Evolución de cantidad de rentas en el tiempo en dolares")
plt.xlabel("Tiempo")
plt.ylabel("Cantidad Rentas")
plt.xticks(numeros, cantidadRentEnAniosEnDolares['created_on'])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook

numeros = list(range(0, len(cantidadRentEnAniosEnPesos['created_on'])))
plt.bar(numeros, cantidadRentEnAniosEnPesos['cantidad'])
plt.suptitle("Evolución de cantidad de rentas en el tiempo en pesos")
plt.xlabel("Tiempo")
plt.ylabel("Cantidad Rentas")
plt.xticks(numeros, cantidadRentEnAniosEnPesos['created_on'])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#analizamos el precio de los lugares a lo largo del tiempo

aux = dsRent.groupby(['place_name', 'created_on']).mean().reset_index().sort_values(by = 'price',ascending= False)[['place_name', 'created_on','preciosEnArs']]
aux
# Out:
#                            place_name created_on  preciosEnArs
# 6139                     Cruz del Eje   20170414  1.111111e+06
# 6436                          Córdoba   20160602  9.750000e+05
# 12198                        Martínez   20150501  8.000000e+05
# 17112                         Pinamar   20151108  8.000000e+05
# 9180                         La Falda   20140924  5.850000e+05
# 26545                      Villa Rosa   20170729  5.500000e+05
# 6120            Country Nuevo Quilmes   20170212  5.500000e+05
# 2766                 Belén de Escobar   20170719  5.150000e+05
# 5641           Concepción del Uruguay   20161020  4.500000e+05
# 14893                            Once   20141112  3.950000e+05
# 21690                      San Isidro   20170307  3.545000e+05
# 6569                          Córdoba   20170217  3.500000e+05
# 21536                      San Isidro   20150501  3.400000e+05
# 23435                        Santa Fe   20170702  3.333330e+05
# 1848                     Barrio Norte   20161212  3.300000e+05
# 6580                          Córdoba   20170322  3.238600e+05
# 71                    Acacias Blancas   20151130  3.232230e+05
# 490                           Almagro   20150924  3.200000e+05
# 20608                      Río Grande   20170704  3.000000e+05
# 6353                          Córdoba   20150729  3.000000e+05
# 18695                         Quilmes   20170719  2.956000e+05
# 20616                        Río Tala   20170719  5.206667e+05
# 17284                         Pinamar   20170314  2.800000e+05
# 8638                       Hurlingham   20151023  2.564100e+05
# 19609            Remedios de Escalada   20170428  2.500000e+05
# 14890                            Once   20140921  2.500000e+05
# 1744                     Barrio Norte   20150729  2.500000e+05
# 8679                       Hurlingham   20170719  2.444133e+05
# 23059                       San Telmo   20141101  2.300000e+05
# 20525                         Rosario   20170726  2.202857e+05
# ...                               ...        ...           ...
# 26460                Villa Paranacito   20131129           NaN
# 26492                Villa Pueyrredón   20150716           NaN
# 26565                 Villa Sarmiento   20130505           NaN
# 26567                 Villa Sarmiento   20130719           NaN
# 26578                 Villa Sarmiento   20141121           NaN
# 26628                     Villa Tesei   20140614           NaN
# 26630                     Villa Tesei   20140730           NaN
# 26740                   Villa Urquiza   20140919           NaN
# 26756                   Villa Urquiza   20141119           NaN
# 26863                   Villa Urquiza   20170707           NaN
# 26881                   Villa de Mayo   20130207           NaN
# 26882                   Villa de Mayo   20130321           NaN
# 26979                Villa del Parque   20170427           NaN
# 27027                 Virrey del Pino   20141114           NaN
# 27028                 Virrey del Pino   20150425           NaN
# 27073                        Vistalba   20170208           NaN
# 27077                           Wilde   20131002           NaN
# 27107                     Yerba Buena   20140610           NaN
# 27108                     Yerba Buena   20150922           NaN
# 27109                     Yerba Buena   20151120           NaN
# 27110                     Yerba Buena   20160524           NaN
# 27112                     Yerba Buena   20170208           NaN
# 27113                     Yerba Buena   20170224           NaN
# 27114                     Yerba Buena   20170309           NaN
# 27115                     Yerba Buena   20170420           NaN
# 27116                     Yerba Buena   20170426           NaN
# 27120                     Yerba Buena   20170724           NaN
# 27121                     Yerba Buena   20170729           NaN
# 27131                          Zárate   20130524           NaN
# 27159  Área de Promoción El Triángulo   20150721           NaN
#
# [27161 rows x 3 columns]

# %%
# %matplotlib notebook

plt.scatter(aux['created_on'], aux['preciosEnArs'])
plt.suptitle("Evolución de preico en pesos en los lugares a lo largo del tiempo")
plt.xlabel("Tiempo")
plt.ylabel("Precio En Pesos")
#plt.xticks(numeros, cantidadRentEnAniosEnPesos['created_on'])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
